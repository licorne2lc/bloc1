# %% [markdown]
# # DATA WHAREHOUSE (ETL)

# %% [markdown]
# ## Import

# %%
# Traitement et manipulation des données
import pandas as pd
import os
import re

# connect to S3
import boto3

# Connexion base de données
from sqlalchemy import create_engine

# Gestion des variables d'environnement
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Init

# %%
PASSWORD = os.getenv("PASSWORD")
HOSTNAME = os.getenv("HOSTNAME") 
DBNAME = os.getenv("DBNAME")

# Configuration S3
bucket = os.getenv("AWS_BUCKET_NAME")
folder = os.getenv("AWS_BUCKET_FOLDER")
region = os.getenv("AWS_REGION")
access_key = os.getenv("aws_access_key_id")
secret_key = os.getenv("aws_secret_access_key")

# %%
def extract_from_s3(filename):
    """
    Récupère un fichier CSV depuis un bucket S3 et retourne un DataFrame.
    """
    if not all([bucket, folder, access_key, secret_key]):
        raise ValueError("❌ Une ou plusieurs variables d'environnement S3 sont manquantes.")

    # Initialisation du client S3
    s3 = boto3.client(
        "s3",
        region_name=region,
        aws_access_key_id=access_key,
        aws_secret_access_key=secret_key
    )

    # Clé S3 complète
    key = f"{folder}/{filename}"

    try:
        obj = s3.get_object(Bucket=bucket, Key=key)
        df = pd.read_csv(obj['Body'], encoding='utf-8-sig')
        print(f"[✅] Fichier '{filename}' extrait depuis s3://{bucket}/{key}")
        return df
    except Exception as e:
        print(f"[❌] Erreur lors de l'extraction de '{filename}' : {e}")
        return None

# %% [markdown]
# ## Pipeline ETL City data

# %% [markdown]
# ### Extract

# %%
df_extract_city = extract_from_s3('df_city.csv')
if df_extract_city is not None:
    display(df_extract_city.head())
# Out:
# [✅] Fichier 'df_city.csv' extrait depuis s3://licorne2lc-kayak/Kayack/df_city.csv
#     City_id               City   Latitude  Longitude
# 0  FR000001  Mont Saint Michel  48.635954  -1.511460
# 1  FR000002            St Malo  48.649518  -2.026041
# 2  FR000003             Bayeux  49.276462  -0.702474
# 3  FR000004           Le Havre  49.493898   0.107973
# 4  FR000005              Rouen  49.440459   1.093966

# %% [markdown]
# ### Transform

# %%
df_trans_city = df_extract_city.copy()

# Renommage des colonnes pour éviter les conflits
df_trans_city.rename(columns={"Latitude": "City_lat",
                                "Longitude": "City_long"},
                                inplace=True)

# export CSV
df_trans_city.to_csv("D:/jedha/full_stack/projet/Scraping_Kayak/df_trans_city.csv", index=False, encoding="utf-8-sig")
print("[✅] df_trans_city exporté.")

df_trans_city.head()
# Out:
# [✅] df_trans_city exporté.
#     City_id               City   City_lat  City_long
# 0  FR000001  Mont Saint Michel  48.635954  -1.511460
# 1  FR000002            St Malo  48.649518  -2.026041
# 2  FR000003             Bayeux  49.276462  -0.702474
# 3  FR000004           Le Havre  49.493898   0.107973
# 4  FR000005              Rouen  49.440459   1.093966

# %% [markdown]
# ### Load

# %%
engine = create_engine(f"postgresql+psycopg2://licorne2lc:{PASSWORD}@{HOSTNAME}/{DBNAME}", echo=True)

df_trans_city.to_sql("df_trans_city", engine, if_exists="replace", index=False)
# Out:
# 2025-07-08 08:01:51,676 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-07-08 08:01:51,676 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:51,691 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-07-08 08:01:51,691 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:51,691 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-07-08 08:01:51,691 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:51,709 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-08 08:01:51,720 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:51,720 INFO sqlalchemy.engine.Engine [generated in 0.00052s] {'table_name': 'df_trans_city', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:51,729 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:51,729 INFO sqlalchemy.engine.Engine [cached since 0.01396s ago] {'table_name': 'df_trans_city', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:51,742 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:51,742 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:51,742 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:51,742 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {'param_1': 'v', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:51,755 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:51,755 INFO sqlalchemy.engine.Engine [cached since 0.007729s ago] {'param_1': 'm', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:51,766 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_attribute.attname AS name, pg_catalog.format_type(pg_catalog.pg_attribute.atttypid, pg_catalog.pg_attribute.atttypmod) AS format_type, (SELECT pg_catalog.pg_get_expr(pg_catalog.pg_attrdef.adbin, pg_catalog.pg_attrdef.adrelid) AS pg_get_expr_1
# FROM pg_catalog.pg_attrdef
# WHERE pg_catalog.pg_attrdef.adrelid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attrdef.adnum = pg_catalog.pg_attribute.attnum AND pg_catalog.pg_attribute.atthasdef) AS "default", pg_catalog.pg_attribute.attnotnull AS not_null, pg_catalog.pg_class.relname AS table_name, pg_catalog.pg_description.description AS comment, pg_catalog.pg_attribute.attgenerated AS generated, (SELECT json_build_object(%(json_build_object_2)s, pg_catalog.pg_attribute.attidentity = %(attidentity_1)s, %(json_build_object_3)s, pg_catalog.pg_sequence.seqstart, %(json_build_object_4)s, pg_catalog.pg_sequence.seqincrement, %(json_build_object_5)s, pg_catalog.pg_sequence.seqmin, %(json_build_object_6)s, pg_catalog.pg_sequence.seqmax, %(json_build_object_7)s, pg_catalog.pg_sequence.seqcache, %(json_build_object_8)s, pg_catalog.pg_sequence.seqcycle) AS json_build_object_1
# FROM pg_catalog.pg_sequence
# WHERE pg_catalog.pg_attribute.attidentity != %(attidentity_2)s AND pg_catalog.pg_sequence.seqrelid = CAST(CAST(pg_catalog.pg_get_serial_sequence(CAST(CAST(pg_catalog.pg_attribute.attrelid AS REGCLASS) AS TEXT), pg_catalog.pg_attribute.attname) AS REGCLASS) AS OID)) AS identity_options
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_class.oid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attribute.attnum > %(attnum_1)s AND NOT pg_catalog.pg_attribute.attisdropped LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_description.objsubid = pg_catalog.pg_attribute.attnum JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_attribute.attnum
# 2025-07-08 08:01:51,766 INFO sqlalchemy.engine.Engine [generated in 0.00052s] {'json_build_object_2': 'always', 'attidentity_1': 'a', 'json_build_object_3': 'start', 'json_build_object_4': 'increment', 'json_build_object_5': 'minvalue', 'json_build_object_6': 'maxvalue', 'json_build_object_7': 'cache', 'json_build_object_8': 'cycle', 'attidentity_2': '', 'attnum_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_city'}
# 2025-07-08 08:01:51,779 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.format_type(pg_catalog.pg_type.typbasetype, pg_catalog.pg_type.typtypmod) AS attype, NOT pg_catalog.pg_type.typnotnull AS nullable, pg_catalog.pg_type.typdefault AS "default", pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, domain_constraints.condefs, domain_constraints.connames
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_constraint.contypid AS contypid, array_agg(pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s)) AS condefs, array_agg(pg_catalog.pg_constraint.conname) AS connames
# FROM pg_catalog.pg_constraint
# WHERE pg_catalog.pg_constraint.contypid != %(contypid_1)s GROUP BY pg_catalog.pg_constraint.contypid) AS domain_constraints ON pg_catalog.pg_type.oid = domain_constraints.contypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2025-07-08 08:01:51,781 INFO sqlalchemy.engine.Engine [generated in 0.00076s] {'pg_get_constraintdef_1': True, 'contypid_1': 0, 'typtype_1': 'd'}
# 2025-07-08 08:01:51,792 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, lbl_agg.labels AS labels
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_enum.enumtypid AS enumtypid, array_agg(pg_catalog.pg_enum.enumlabel ORDER BY pg_catalog.pg_enum.enumsortorder) AS labels
# FROM pg_catalog.pg_enum GROUP BY pg_catalog.pg_enum.enumtypid) AS lbl_agg ON pg_catalog.pg_type.oid = lbl_agg.enumtypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2025-07-08 08:01:51,792 INFO sqlalchemy.engine.Engine [generated in 0.00079s] {'typtype_1': 'e'}
# 2025-07-08 08:01:51,792 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.oid, pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2025-07-08 08:01:51,792 INFO sqlalchemy.engine.Engine [generated in 0.00091s] {'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_city'}
# 2025-07-08 08:01:51,807 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2025-07-08 08:01:51,807 INFO sqlalchemy.engine.Engine [generated in 0.00063s] {'generate_subscripts_1': 1, 'contype': 'p', 'oids_1': 16759}
# 2025-07-08 08:01:51,823 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, nsp_ref.nspname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_class AS cls_ref ON cls_ref.oid = pg_catalog.pg_constraint.confrelid LEFT OUTER JOIN pg_catalog.pg_namespace AS nsp_ref ON cls_ref.relnamespace = nsp_ref.oid LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2025-07-08 08:01:51,823 INFO sqlalchemy.engine.Engine [generated in 0.00058s] {'pg_get_constraintdef_1': True, 'contype_1': 'f', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_city'}
# 2025-07-08 08:01:51,832 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_index.indrelid, cls_idx.relname AS relname_index, pg_catalog.pg_index.indisunique, pg_catalog.pg_constraint.conrelid IS NOT NULL AS has_constraint, pg_catalog.pg_index.indoption, cls_idx.reloptions, pg_catalog.pg_am.amname, CASE WHEN (pg_catalog.pg_index.indpred IS NOT NULL) THEN pg_catalog.pg_get_expr(pg_catalog.pg_index.indpred, pg_catalog.pg_index.indrelid) ELSE NULL END AS filter_definition, pg_catalog.pg_index.indnkeyatts, idx_cols.elements, idx_cols.elements_is_expr
# FROM pg_catalog.pg_index JOIN pg_catalog.pg_class AS cls_idx ON pg_catalog.pg_index.indexrelid = cls_idx.oid JOIN pg_catalog.pg_am ON cls_idx.relam = pg_catalog.pg_am.oid LEFT OUTER JOIN (SELECT idx_attr.indexrelid AS indexrelid, min(idx_attr.indrelid) AS min_1, array_agg(idx_attr.element ORDER BY idx_attr.ord) AS elements, array_agg(idx_attr.is_expr ORDER BY idx_attr.ord) AS elements_is_expr
# FROM (SELECT idx.indexrelid AS indexrelid, idx.indrelid AS indrelid, idx.ord AS ord, CASE WHEN (idx.attnum = %(attnum_1)s) THEN pg_catalog.pg_get_indexdef(idx.indexrelid, idx.ord + %(ord_1)s, %(pg_get_indexdef_1)s) ELSE pg_catalog.pg_attribute.attname END AS element, idx.attnum = %(attnum_2)s AS is_expr
# FROM (SELECT pg_catalog.pg_index.indexrelid AS indexrelid, pg_catalog.pg_index.indrelid AS indrelid, unnest(pg_catalog.pg_index.indkey) AS attnum, generate_subscripts(pg_catalog.pg_index.indkey, %(generate_subscripts_1)s) AS ord
# FROM pg_catalog.pg_index
# WHERE NOT pg_catalog.pg_index.indisprimary AND pg_catalog.pg_index.indrelid IN (%(oids_1)s)) AS idx LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_attribute.attnum = idx.attnum AND pg_catalog.pg_attribute.attrelid = idx.indrelid
# WHERE idx.indrelid IN (%(oids_1)s)) AS idx_attr GROUP BY idx_attr.indexrelid) AS idx_cols ON pg_catalog.pg_index.indexrelid = idx_cols.indexrelid LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_index.indrelid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_index.indexrelid = pg_catalog.pg_constraint.conindid AND pg_catalog.pg_constraint.contype = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s])
# WHERE pg_catalog.pg_index.indrelid IN (%(oids_1)s) AND NOT pg_catalog.pg_index.indisprimary ORDER BY pg_catalog.pg_index.indrelid, cls_idx.relname
# 2025-07-08 08:01:51,834 INFO sqlalchemy.engine.Engine [generated in 0.00055s] {'attnum_1': 0, 'ord_1': 1, 'pg_get_indexdef_1': True, 'attnum_2': 0, 'generate_subscripts_1': 1, 'param_1': 'p', 'param_2': 'u', 'param_3': 'x', 'oids_1': 16759}
# 2025-07-08 08:01:51,842 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2025-07-08 08:01:51,842 INFO sqlalchemy.engine.Engine [cached since 0.02975s ago] {'generate_subscripts_1': 1, 'contype': 'u', 'oids_1': 16759}
# 2025-07-08 08:01:51,842 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_class.oid = pg_catalog.pg_description.objoid AND pg_catalog.pg_description.objsubid = %(objsubid_1)s JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2025-07-08 08:01:51,842 INFO sqlalchemy.engine.Engine [generated in 0.00044s] {'objsubid_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_city'}
# 2025-07-08 08:01:51,858 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2025-07-08 08:01:51,858 INFO sqlalchemy.engine.Engine [generated in 0.00072s] {'pg_get_constraintdef_1': True, 'contype_1': 'c', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_city'}
# 2025-07-08 08:01:51,858 INFO sqlalchemy.engine.Engine
# DROP TABLE df_trans_city
# 2025-07-08 08:01:51,858 INFO sqlalchemy.engine.Engine [no key 0.00040s] {}
# 2025-07-08 08:01:51,873 INFO sqlalchemy.engine.Engine
# CREATE TABLE df_trans_city (
# 	"City_id" TEXT,
# 	"City" TEXT,
# 	"City_lat" FLOAT(53),
# 	"City_long" FLOAT(53)
# )
#
#
# 2025-07-08 08:01:51,873 INFO sqlalchemy.engine.Engine [no key 0.00044s] {}
# 2025-07-08 08:01:51,873 INFO sqlalchemy.engine.Engine INSERT INTO df_trans_city ("City_id", "City", "City_lat", "City_long") VALUES (%(City_id__0)s, %(City__0)s, %(City_lat__0)s, %(City_long__0)s), (%(City_id__1)s, %(City__1)s, %(City_lat__1)s, %(City_long__1)s), (%(City_id__2)s, %(City__2)s, %(City_lat ... 2136 characters truncated ... _lat__33)s, %(City_long__33)s), (%(City_id__34)s, %(City__34)s, %(City_lat__34)s, %(City_long__34)s)
# 2025-07-08 08:01:51,873 INFO sqlalchemy.engine.Engine [generated in 0.00009s (insertmanyvalues)] {'City_lat__0': 48.6359541, 'City_id__0': 'FR000001', 'City_long__0': -1.51146, 'City__0': 'Mont Saint Michel', 'City_lat__1': 48.649518, 'City_id__1': 'FR000002', 'City_long__1': -2.0260409, 'City__1': 'St Malo', 'City_lat__2': 49.2764624, 'City_id__2': 'FR000003', 'City_long__2': -0.7024738, 'City__2': 'Bayeux', 'City_lat__3': 49.4938975, 'City_id__3': 'FR000004', 'City_long__3': 0.1079732, 'City__3': 'Le Havre', 'City_lat__4': 49.4404591, 'City_id__4': 'FR000005', 'City_long__4': 1.0939658, 'City__4': 'Rouen', 'City_lat__5': 48.8588897, 'City_id__5': 'FR000006', 'City_long__5': 2.320041, 'City__5': 'Paris', 'City_lat__6': 49.8941708, 'City_id__6': 'FR000007', 'City_long__6': 2.2956951, 'City__6': 'Amiens', 'City_lat__7': 50.6365654, 'City_id__7': 'FR000008', 'City_long__7': 3.0635282, 'City__7': 'Lille', 'City_lat__8': 48.584614, 'City_id__8': 'FR000009', 'City_long__8': 7.7507127, 'City__8': 'Strasbourg', 'City_lat__9': 48.2494107, 'City_id__9': 'FR000010', 'City_long__9': 7.3443202, 'City__9': 'Chateau du Haut Koenigsbourg', 'City_lat__10': 48.0777517, 'City_id__10': 'FR000011', 'City_long__10': 7.3579641, 'City__10': 'Colmar', 'City_lat__11': 48.0447968, 'City_id__11': 'FR000012', 'City_long__11': 7.3079618, 'City__11': 'Eguisheim', 'City_lat__12': 47.2380222, 'City_id__12': 'FR000013' ... 40 parameters truncated ... 'City_long__22': 4.8059012, 'City__22': 'Avignon', 'City_lat__23': 44.0121279, 'City_id__23': 'FR000024', 'City_long__23': 4.4196718, 'City__23': 'Uzes', 'City_lat__24': 43.8374249, 'City_id__24': 'FR000025', 'City_long__24': 4.3600687, 'City__24': 'Nimes', 'City_lat__25': 43.5661521, 'City_id__25': 'FR000026', 'City_long__25': 4.19154, 'City__25': 'Aigues Mortes', 'City_lat__26': 43.4515922, 'City_id__26': 'FR000027', 'City_long__26': 4.4277202, 'City__26': 'Saintes Maries de la mer', 'City_lat__27': 42.52505, 'City_id__27': 'FR000028', 'City_long__27': 3.0831554, 'City__27': 'Collioure', 'City_lat__28': 43.2130358, 'City_id__28': 'FR000029', 'City_long__28': 2.3491069, 'City__28': 'Carcassonne', 'City_lat__29': 42.9455368, 'City_id__29': 'FR000030', 'City_long__29': 1.4065544, 'City__29': 'Ariege', 'City_lat__30': 43.6044622, 'City_id__30': 'FR000031', 'City_long__30': 1.4442469, 'City__30': 'Toulouse', 'City_lat__31': 44.0175835, 'City_id__31': 'FR000032', 'City_long__31': 1.3549991, 'City__31': 'Montauban', 'City_lat__32': 43.4711437, 'City_id__32': 'FR000033', 'City_long__32': -1.5527266, 'City__32': 'Biarritz', 'City_lat__33': 43.4945144, 'City_id__33': 'FR000034', 'City_long__33': -1.4736657, 'City__33': 'Bayonne', 'City_lat__34': 46.159732, 'City_id__34': 'FR000035', 'City_long__34': -1.1515951, 'City__34': 'La Rochelle'}
# 2025-07-08 08:01:51,889 INFO sqlalchemy.engine.Engine COMMIT
# 35

# %% [markdown]
# ## Pipeline ETL hotels data

# %% [markdown]
# ### Extract

# %%
df_extract_hotels = extract_from_s3('df_hotels.csv')
if df_extract_hotels is not None:
    display(df_extract_hotels.head())
# Out:
# [✅] Fichier 'df_hotels.csv' extrait depuis s3://licorne2lc-kayak/Kayack/df_hotels.csv
#     City_id               city                        nom  \
# 0  FR000001  Mont Saint Michel     Le Relais Saint Michel
# 1  FR000001  Mont Saint Michel                 Hôtel Vert
# 2  FR000001  Mont Saint Michel  Mercure Mont Saint Michel
# 3  FR000001  Mont Saint Michel              Hotel Gabriel
# 4  FR000001  Mont Saint Michel       Auberge Saint Pierre
#
#                                                  url note  \
# 0  https://www.booking.com/hotel/fr/le-relais-sai...  8,2
# 1  https://www.booking.com/hotel/fr/vert.fr.html?...  8,0
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...  8,3
# 3  https://www.booking.com/hotel/fr/hotel-gabriel...  8,2
# 4  https://www.booking.com/hotel/fr/auberge-saint...  8,3
#
#                                  latlong  \
# 0     48.6175872716489,-1.51039615273476
# 1  48.61470048629041,-1.5096169710159302
# 2   48.61424652959294,-1.510545015335083
# 3   48.61538141368341,-1.510709971189499
# 4  48.63568797869143,-1.5098825097084045
#
#                                              adresse  \
# 0     La Caserne, 50170 Le Mont-Saint-Michel, France
# 1     La Caserne, 50170 Le Mont-Saint-Michel, France
# 2     La Caserne, 50170 Le Mont-Saint-Michel, France
# 3  Route du Mont Saint Michel, 50170 Le Mont-Sain...
# 4     Grande Rue, 50170 Le Mont-Saint-Michel, France
#
#                                         points_forts
# 0  ['Ses points forts', 'Parking', 'Petit-déjeune...
# 1  ['Ses points forts', 'LA SALICORNE', 'Restaura...
# 2  ['Ses points forts', 'Parking', 'Petit-déjeune...
# 3  ['Ses points forts', 'LA SALICORNE', 'LE PRE S...
# 4              ['Ses points forts', 'Restaurant #1']

# %% [markdown]
# ### Transform

# %%
df_trans_hotels = df_extract_hotels.copy()

# Harmonisation de la casse des colonnes
df_trans_hotels.columns = [col.strip().lower().replace(" ", "_").capitalize() for col in df_trans_hotels.columns]

# Séparation de la colonne latlong en deux colonnes numériques
df_trans_hotels[["Hotel_lat", "Hotel_long"]] = (
    df_trans_hotels["Latlong"].str.split(",", expand=True).astype(float)
)

# Suppression de la colonne latlong
df_trans_hotels.drop(columns=["Latlong"], inplace=True)

# Nettoyage de la colonne points_forts avec regex
def clean_points_forts_regex(text):
    # Supprimer "Ses points forts" avec ou sans majuscules
    text = re.sub(r"'?Ses points forts'?,?\s*", "", text, flags=re.IGNORECASE)

    # Supprimer les crochets restants
    text = re.sub(r"^\[|\]$", "", text.strip())

    # Split, strip et nettoyage
    items = [re.sub(r"^['\"\s,]+|['\"\s,]+$", "", part) for part in text.split(",")]

    # Transformation des "#chiffre" → "chiffre*"
    items = [re.sub(r"#(\d+)", r"\1*", item) for item in items if item]

    return items

# Application du nettoyage
df_trans_hotels["Points_forts"] = df_trans_hotels["Points_forts"].apply(clean_points_forts_regex)

# export CSV
df_trans_hotels.to_csv("D:/jedha/full_stack/projet/Scraping_Kayak/df_trans_hotels.csv", index=False, encoding="utf-8-sig")
print("[✅] df_trans_hotels exporté.")

df_trans_hotels
# Out:
# [✅] df_trans_hotels exporté.
#       City_id               City  \
# 0    FR000001  Mont Saint Michel
# 1    FR000001  Mont Saint Michel
# 2    FR000001  Mont Saint Michel
# 3    FR000001  Mont Saint Michel
# 4    FR000001  Mont Saint Michel
# ..        ...                ...
# 868  FR000035        La Rochelle
# 869  FR000035        La Rochelle
# 870  FR000035        La Rochelle
# 871  FR000035        La Rochelle
# 872  FR000035        La Rochelle
#
#                                                    Nom  \
# 0                               Le Relais Saint Michel
# 1                                           Hôtel Vert
# 2                            Mercure Mont Saint Michel
# 3                                        Hotel Gabriel
# 4                                 Auberge Saint Pierre
# ..                                                 ...
# 868      Vintage calme sur jardin en centre historique
# 869     Tour de Nesle La Rochelle Vieux Port 3 etoiles
# 870                                   Hôtel Les Brises
# 871  Appartement Charlie, Wifi, Charme, Centre Hist...
# 872  Ambre Appart-Wifi-Terrasse-Parking-Terrasse-2 ...
#
#                                                    Url Note  \
# 0    https://www.booking.com/hotel/fr/le-relais-sai...  8,2
# 1    https://www.booking.com/hotel/fr/vert.fr.html?...  8,0
# 2    https://www.booking.com/hotel/fr/mont-saint-mi...  8,3
# 3    https://www.booking.com/hotel/fr/hotel-gabriel...  8,2
# 4    https://www.booking.com/hotel/fr/auberge-saint...  8,3
# ..                                                 ...  ...
# 868  https://www.booking.com/hotel/fr/vintage-calme...  9,6
# 869  https://www.booking.com/hotel/fr/de-la-tour-de...  8,7
# 870  https://www.booking.com/hotel/fr/hotellesbrise...  8,6
# 871  https://www.booking.com/hotel/fr/appartement-c...  8,3
# 872  https://www.booking.com/hotel/fr/ambre-appart-...  9,2
#
#                                                Adresse  \
# 0       La Caserne, 50170 Le Mont-Saint-Michel, France
# 1       La Caserne, 50170 Le Mont-Saint-Michel, France
# 2       La Caserne, 50170 Le Mont-Saint-Michel, France
# 3    Route du Mont Saint Michel, 50170 Le Mont-Sain...
# 4       Grande Rue, 50170 Le Mont-Saint-Michel, France
# ..                                                 ...
# 868       11 Rue Buffeterie, 17000 La Rochelle, France
# 869    2, Quai Louis Durand, 17000 La Rochelle, France
# 870  Chemin de la digue Richelieu, 17000 La Rochell...
# 871         1 Rue Chaudrier, 17000 La Rochelle, France
# 872          40 Rue Berlioz, 17000 La Rochelle, France
#
#                                           Points_forts  Hotel_lat  Hotel_long
# 0    [Parking, Petit-déjeuner disponible, Vue, Anim...  48.617587   -1.510396
# 1                        [LA SALICORNE, Restaurant 2*]  48.614700   -1.509617
# 2    [Parking, Petit-déjeuner disponible, Animaux a...  48.614247   -1.510545
# 3                          [LA SALICORNE, LE PRE SALE]  48.615381   -1.510710
# 4                                      [Restaurant 1*]  48.635688   -1.509883
# ..                                                 ...        ...         ...
# 868  [L’hébergement entier est pour vous, Vue, Équi...  46.162419   -1.148105
# 869  [Petit-déjeuner disponible, Vue, Animaux admis...  46.158097   -1.150362
# 870                                                 []  46.153458   -1.174386
# 871  [L’hébergement entier est pour vous, Vue, Équi...  46.160301   -1.153571
# 872  [L’hébergement entier est pour vous, Parking, ...  46.159007   -1.135610
#
# [873 rows x 9 columns]

# %% [markdown]
# ### Load

# %%
engine = create_engine(f"postgresql+psycopg2://licorne2lc:{PASSWORD}@{HOSTNAME}/{DBNAME}", echo=True)

df_trans_hotels.to_sql("df_trans_hotels", engine, if_exists="replace", index=False)
# Out:
# 2025-07-08 08:01:52,202 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-07-08 08:01:52,203 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:52,216 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-07-08 08:01:52,216 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:52,226 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-07-08 08:01:52,226 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:52,241 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-08 08:01:52,243 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,243 INFO sqlalchemy.engine.Engine [generated in 0.00056s] {'table_name': 'df_trans_hotels', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,243 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,257 INFO sqlalchemy.engine.Engine [cached since 0.01351s ago] {'table_name': 'df_trans_hotels', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,257 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,257 INFO sqlalchemy.engine.Engine [generated in 0.00059s] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,273 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,273 INFO sqlalchemy.engine.Engine [generated in 0.00050s] {'param_1': 'v', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,273 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,273 INFO sqlalchemy.engine.Engine [cached since 0.008388s ago] {'param_1': 'm', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,289 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_attribute.attname AS name, pg_catalog.format_type(pg_catalog.pg_attribute.atttypid, pg_catalog.pg_attribute.atttypmod) AS format_type, (SELECT pg_catalog.pg_get_expr(pg_catalog.pg_attrdef.adbin, pg_catalog.pg_attrdef.adrelid) AS pg_get_expr_1
# FROM pg_catalog.pg_attrdef
# WHERE pg_catalog.pg_attrdef.adrelid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attrdef.adnum = pg_catalog.pg_attribute.attnum AND pg_catalog.pg_attribute.atthasdef) AS "default", pg_catalog.pg_attribute.attnotnull AS not_null, pg_catalog.pg_class.relname AS table_name, pg_catalog.pg_description.description AS comment, pg_catalog.pg_attribute.attgenerated AS generated, (SELECT json_build_object(%(json_build_object_2)s, pg_catalog.pg_attribute.attidentity = %(attidentity_1)s, %(json_build_object_3)s, pg_catalog.pg_sequence.seqstart, %(json_build_object_4)s, pg_catalog.pg_sequence.seqincrement, %(json_build_object_5)s, pg_catalog.pg_sequence.seqmin, %(json_build_object_6)s, pg_catalog.pg_sequence.seqmax, %(json_build_object_7)s, pg_catalog.pg_sequence.seqcache, %(json_build_object_8)s, pg_catalog.pg_sequence.seqcycle) AS json_build_object_1
# FROM pg_catalog.pg_sequence
# WHERE pg_catalog.pg_attribute.attidentity != %(attidentity_2)s AND pg_catalog.pg_sequence.seqrelid = CAST(CAST(pg_catalog.pg_get_serial_sequence(CAST(CAST(pg_catalog.pg_attribute.attrelid AS REGCLASS) AS TEXT), pg_catalog.pg_attribute.attname) AS REGCLASS) AS OID)) AS identity_options
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_class.oid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attribute.attnum > %(attnum_1)s AND NOT pg_catalog.pg_attribute.attisdropped LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_description.objsubid = pg_catalog.pg_attribute.attnum JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_attribute.attnum
# 2025-07-08 08:01:52,289 INFO sqlalchemy.engine.Engine [generated in 0.00061s] {'json_build_object_2': 'always', 'attidentity_1': 'a', 'json_build_object_3': 'start', 'json_build_object_4': 'increment', 'json_build_object_5': 'minvalue', 'json_build_object_6': 'maxvalue', 'json_build_object_7': 'cache', 'json_build_object_8': 'cycle', 'attidentity_2': '', 'attnum_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_hotels'}
# 2025-07-08 08:01:52,292 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.format_type(pg_catalog.pg_type.typbasetype, pg_catalog.pg_type.typtypmod) AS attype, NOT pg_catalog.pg_type.typnotnull AS nullable, pg_catalog.pg_type.typdefault AS "default", pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, domain_constraints.condefs, domain_constraints.connames
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_constraint.contypid AS contypid, array_agg(pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s)) AS condefs, array_agg(pg_catalog.pg_constraint.conname) AS connames
# FROM pg_catalog.pg_constraint
# WHERE pg_catalog.pg_constraint.contypid != %(contypid_1)s GROUP BY pg_catalog.pg_constraint.contypid) AS domain_constraints ON pg_catalog.pg_type.oid = domain_constraints.contypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2025-07-08 08:01:52,292 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {'pg_get_constraintdef_1': True, 'contypid_1': 0, 'typtype_1': 'd'}
# 2025-07-08 08:01:52,307 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, lbl_agg.labels AS labels
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_enum.enumtypid AS enumtypid, array_agg(pg_catalog.pg_enum.enumlabel ORDER BY pg_catalog.pg_enum.enumsortorder) AS labels
# FROM pg_catalog.pg_enum GROUP BY pg_catalog.pg_enum.enumtypid) AS lbl_agg ON pg_catalog.pg_type.oid = lbl_agg.enumtypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2025-07-08 08:01:52,307 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {'typtype_1': 'e'}
# 2025-07-08 08:01:52,307 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.oid, pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2025-07-08 08:01:52,307 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_hotels'}
# 2025-07-08 08:01:52,325 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2025-07-08 08:01:52,325 INFO sqlalchemy.engine.Engine [generated in 0.00052s] {'generate_subscripts_1': 1, 'contype': 'p', 'oids_1': 16764}
# 2025-07-08 08:01:52,331 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, nsp_ref.nspname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_class AS cls_ref ON cls_ref.oid = pg_catalog.pg_constraint.confrelid LEFT OUTER JOIN pg_catalog.pg_namespace AS nsp_ref ON cls_ref.relnamespace = nsp_ref.oid LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2025-07-08 08:01:52,331 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {'pg_get_constraintdef_1': True, 'contype_1': 'f', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_hotels'}
# 2025-07-08 08:01:52,343 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_index.indrelid, cls_idx.relname AS relname_index, pg_catalog.pg_index.indisunique, pg_catalog.pg_constraint.conrelid IS NOT NULL AS has_constraint, pg_catalog.pg_index.indoption, cls_idx.reloptions, pg_catalog.pg_am.amname, CASE WHEN (pg_catalog.pg_index.indpred IS NOT NULL) THEN pg_catalog.pg_get_expr(pg_catalog.pg_index.indpred, pg_catalog.pg_index.indrelid) ELSE NULL END AS filter_definition, pg_catalog.pg_index.indnkeyatts, idx_cols.elements, idx_cols.elements_is_expr
# FROM pg_catalog.pg_index JOIN pg_catalog.pg_class AS cls_idx ON pg_catalog.pg_index.indexrelid = cls_idx.oid JOIN pg_catalog.pg_am ON cls_idx.relam = pg_catalog.pg_am.oid LEFT OUTER JOIN (SELECT idx_attr.indexrelid AS indexrelid, min(idx_attr.indrelid) AS min_1, array_agg(idx_attr.element ORDER BY idx_attr.ord) AS elements, array_agg(idx_attr.is_expr ORDER BY idx_attr.ord) AS elements_is_expr
# FROM (SELECT idx.indexrelid AS indexrelid, idx.indrelid AS indrelid, idx.ord AS ord, CASE WHEN (idx.attnum = %(attnum_1)s) THEN pg_catalog.pg_get_indexdef(idx.indexrelid, idx.ord + %(ord_1)s, %(pg_get_indexdef_1)s) ELSE pg_catalog.pg_attribute.attname END AS element, idx.attnum = %(attnum_2)s AS is_expr
# FROM (SELECT pg_catalog.pg_index.indexrelid AS indexrelid, pg_catalog.pg_index.indrelid AS indrelid, unnest(pg_catalog.pg_index.indkey) AS attnum, generate_subscripts(pg_catalog.pg_index.indkey, %(generate_subscripts_1)s) AS ord
# FROM pg_catalog.pg_index
# WHERE NOT pg_catalog.pg_index.indisprimary AND pg_catalog.pg_index.indrelid IN (%(oids_1)s)) AS idx LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_attribute.attnum = idx.attnum AND pg_catalog.pg_attribute.attrelid = idx.indrelid
# WHERE idx.indrelid IN (%(oids_1)s)) AS idx_attr GROUP BY idx_attr.indexrelid) AS idx_cols ON pg_catalog.pg_index.indexrelid = idx_cols.indexrelid LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_index.indrelid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_index.indexrelid = pg_catalog.pg_constraint.conindid AND pg_catalog.pg_constraint.contype = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s])
# WHERE pg_catalog.pg_index.indrelid IN (%(oids_1)s) AND NOT pg_catalog.pg_index.indisprimary ORDER BY pg_catalog.pg_index.indrelid, cls_idx.relname
# 2025-07-08 08:01:52,343 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {'attnum_1': 0, 'ord_1': 1, 'pg_get_indexdef_1': True, 'attnum_2': 0, 'generate_subscripts_1': 1, 'param_1': 'p', 'param_2': 'u', 'param_3': 'x', 'oids_1': 16764}
# 2025-07-08 08:01:52,343 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2025-07-08 08:01:52,343 INFO sqlalchemy.engine.Engine [cached since 0.02843s ago] {'generate_subscripts_1': 1, 'contype': 'u', 'oids_1': 16764}
# 2025-07-08 08:01:52,356 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_class.oid = pg_catalog.pg_description.objoid AND pg_catalog.pg_description.objsubid = %(objsubid_1)s JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2025-07-08 08:01:52,356 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {'objsubid_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_hotels'}
# 2025-07-08 08:01:52,374 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2025-07-08 08:01:52,375 INFO sqlalchemy.engine.Engine [generated in 0.00106s] {'pg_get_constraintdef_1': True, 'contype_1': 'c', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_hotels'}
# 2025-07-08 08:01:52,382 INFO sqlalchemy.engine.Engine
# DROP TABLE df_trans_hotels
# 2025-07-08 08:01:52,382 INFO sqlalchemy.engine.Engine [no key 0.00080s] {}
# 2025-07-08 08:01:52,394 INFO sqlalchemy.engine.Engine
# CREATE TABLE df_trans_hotels (
# 	"City_id" TEXT,
# 	"City" TEXT,
# 	"Nom" TEXT,
# 	"Url" TEXT,
# 	"Note" TEXT,
# 	"Adresse" TEXT,
# 	"Points_forts" TEXT,
# 	"Hotel_lat" FLOAT(53),
# 	"Hotel_long" FLOAT(53)
# )
#
#
# 2025-07-08 08:01:52,394 INFO sqlalchemy.engine.Engine [no key 0.00068s] {}
# 2025-07-08 08:01:52,407 INFO sqlalchemy.engine.Engine INSERT INTO df_trans_hotels ("City_id", "City", "Nom", "Url", "Note", "Adresse", "Points_forts", "Hotel_lat", "Hotel_long") VALUES (%(City_id__0)s, %(City__0)s, %(Nom__0)s, %(Url__0)s, %(Note__0)s, %(Adresse__0)s, %(Points_forts__0)s, %(Hotel_lat__0) ... 138469 characters truncated ... )s, %(Note__872)s, %(Adresse__872)s, %(Points_forts__872)s, %(Hotel_lat__872)s, %(Hotel_long__872)s)
# 2025-07-08 08:01:52,407 INFO sqlalchemy.engine.Engine [generated in 0.00241s (insertmanyvalues)] {'Note__0': '8,2', 'City_id__0': 'FR000001', 'Points_forts__0': ['Parking', 'Petit-déjeuner disponible', 'Vue', 'Animaux admis', 'Équipements de cuisine', 'Le Relais Saint Michel'], 'Hotel_long__0': -1.51039615273476, 'Nom__0': 'Le Relais Saint Michel', 'Adresse__0': 'La Caserne, 50170 Le Mont-Saint-Michel, France', 'Hotel_lat__0': 48.6175872716489, 'Url__0': 'https://www.booking.com/hotel/fr/le-relais-saint-michel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgNWARoTYgBAZgBD ... (160 characters truncated) ... oup_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=review_score%3D80&srpvid=56a06e4db3c80481&srepoch=1742744476&from=searchresults', 'City__0': 'Mont Saint Michel', 'Note__1': '8,0', 'City_id__1': 'FR000001', 'Points_forts__1': ['LA SALICORNE', 'Restaurant 2*'], 'Hotel_long__1': -1.5096169710159302, 'Nom__1': 'Hôtel Vert', 'Adresse__1': 'La Caserne, 50170 Le Mont-Saint-Michel, France', 'Hotel_lat__1': 48.61470048629041, 'Url__1': 'https://www.booking.com/hotel/fr/vert.fr.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgNWARoTYgBAZgBDbgBF8gBDNgBAegBAfg ... (142 characters truncated) ... oup_children=0&req_children=0&hpos=2&hapos=2&sr_order=popularity&nflt=review_score%3D80&srpvid=56a06e4db3c80481&srepoch=1742744476&from=searchresults', 'City__1': 'Mont Saint Michel', 'Note__2': '8,3', 'City_id__2': 'FR000001', 'Points_forts__2': ['Parking', 'Petit-déjeuner disponible', 'Animaux admis', 'Équipements de cuisine', 'Accessibilité', 'LE PRE SALE'], 'Hotel_long__2': -1.510545015335083, 'Nom__2': 'Mercure Mont Saint Michel', 'Adresse__2': 'La Caserne, 50170 Le Mont-Saint-Michel, France', 'Hotel_lat__2': 48.61424652959294, 'Url__2': 'https://www.booking.com/hotel/fr/mont-saint-michel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgNWARoTYgBAZgBDbgBF8 ... (155 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=56a06e4db3c80481&srepoch=1742744476&from=searchresults', 'City__2': 'Mont Saint Michel', 'Note__3': '8,2', 'City_id__3': 'FR000001', 'Points_forts__3': ['LA SALICORNE', 'LE PRE SALE'], 'Hotel_long__3': -1.510709971189499, 'Nom__3': 'Hotel Gabriel', 'Adresse__3': 'Route du Mont Saint Michel, 50170 Le Mont-Saint-Michel, France', 'Hotel_lat__3': 48.61538141368341, 'Url__3': 'https://www.booking.com/hotel/fr/hotel-gabriel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgNWARoTYgBAZgBDbgBF8gBDN ... (151 characters truncated) ... oup_children=0&req_children=0&hpos=4&hapos=4&sr_order=popularity&nflt=review_score%3D80&srpvid=56a06e4db3c80481&srepoch=1742744476&from=searchresults', 'City__3': 'Mont Saint Michel', 'Note__4': '8,3', 'City_id__4': 'FR000001', 'Points_forts__4': ['Restaurant 1*'], 'Hotel_long__4': -1.5098825097084045, 'Nom__4': 'Auberge Saint Pierre', 'Adresse__4': 'Grande Rue, 50170 Le Mont-Saint-Michel, France', 'Hotel_lat__4': 48.63568797869143, 'Url__4': 'https://www.booking.com/hotel/fr/auberge-saint-pierre.fr.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgNWARoTYgBAZgBDbg ... (158 characters truncated) ... oup_children=0&req_children=0&hpos=5&hapos=5&sr_order=popularity&nflt=review_score%3D80&srpvid=56a06e4db3c80481&srepoch=1742744476&from=searchresults', 'City__4': 'Mont Saint Michel', 'Note__5': '8,3', 'City_id__5': 'FR000001', 'Points_forts__5': ['Parking', 'Petit-déjeuner disponible', 'Vue', 'Animaux admis', 'Équipements de cuisine', 'La Salicorne', 'Le Pré Salé'], 'Hotel_long__5': -1.510905772447586, 'Nom__5': 'Le Relais Du Roy' ... 7757 parameters truncated ... 'Nom__867': 'Le Champlain', 'Adresse__867': '30, Rue Rambaud , 17000 La Rochelle, France', 'Hotel_lat__867': 46.16357605073282, 'Url__867': 'https://www.booking.com/hotel/fr/best-western-champlain-france-angleterre.fr.html? ...
# 2025-07-08 08:01:52,473 INFO sqlalchemy.engine.Engine COMMIT
# 873

# %% [markdown]
# ## Pipeline ETL weather data

# %% [markdown]
# ### Extract

# %%
df_extract_meteo_forecast = extract_from_s3('df_meteo_forecast.csv')
if df_extract_meteo_forecast is not None:
    display(df_extract_meteo_forecast.head())
# Out:
# [✅] Fichier 'df_meteo_forecast.csv' extrait depuis s3://licorne2lc-kayak/Kayack/df_meteo_forecast.csv
#     City_id               City   Latitude  Longitude        Date  \
# 0  FR000001  Mont Saint Michel  48.635954   -1.51146  2025-07-08
# 1  FR000001  Mont Saint Michel  48.635954   -1.51146  2025-07-09
# 2  FR000001  Mont Saint Michel  48.635954   -1.51146  2025-07-10
# 3  FR000001  Mont Saint Michel  48.635954   -1.51146  2025-07-11
# 4  FR000001  Mont Saint Michel  48.635954   -1.51146  2025-07-12
#
#    Température max (°C)  Vent max (m/s)  Force vent  Angle vent (°)  \
# 0                    19               7           4             311
# 1                    23               5           3             326
# 2                    27               6           4             325
# 3                    31               6           4              52
# 4                    32               6           4              61
#
#    Indice UV Icon Emoji          Description
# 0       7.73  10d    🌦️  Pluie intermittente
# 1       7.77  01d    ☀️   Ciel dégagé (jour)
# 2       7.97  01d    ☀️   Ciel dégagé (jour)
# 3       7.88  02d    🌤️   Peu nuageux (jour)
# 4       7.72  02d    🌤️   Peu nuageux (jour)

# %% [markdown]
# ### Transform

# %%
df_trans_weather = df_extract_meteo_forecast.copy()

# Nettoyage de la colonne "Description" : suppression du contenu entre parenthèses
def remove_parentheses_content(text):
    return re.sub(r"\s*\([^)]*\)", "", str(text)).strip()

df_trans_weather["Description"] = df_trans_weather["Description"].apply(remove_parentheses_content)

# Renommage des colonnes pour éviter les conflits
df_trans_weather.rename(columns={"Latitude": "City_lat",
                              "Longitude": "City_long",
                              "Description":"Weather_description"},
                              inplace=True)

# export CSV
df_trans_weather.to_csv("D:/jedha/full_stack/projet/Scraping_Kayak/df_trans_weather.csv", index=False, encoding="utf-8-sig")
print("[✅] df_trans_weather exporté.")

df_trans_weather.head(1)
# Out:
# [✅] df_trans_weather exporté.
#     City_id               City   City_lat  City_long        Date  \
# 0  FR000001  Mont Saint Michel  48.635954   -1.51146  2025-07-08
#
#    Température max (°C)  Vent max (m/s)  Force vent  Angle vent (°)  \
# 0                    19               7           4             311
#
#    Indice UV Icon Emoji  Weather_description
# 0       7.73  10d    🌦️  Pluie intermittente

# %% [markdown]
# ### Load

# %%
engine = create_engine(f"postgresql+psycopg2://licorne2lc:{PASSWORD}@{HOSTNAME}/{DBNAME}", echo=True)

df_trans_weather.to_sql("df_trans_weather", engine, if_exists="replace", index=False)
# Out:
# 2025-07-08 08:01:52,679 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-07-08 08:01:52,679 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:52,695 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-07-08 08:01:52,695 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:52,710 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-07-08 08:01:52,711 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:52,712 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-08 08:01:52,712 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,712 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {'table_name': 'df_trans_weather', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,735 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,736 INFO sqlalchemy.engine.Engine [cached since 0.01256s ago] {'table_name': 'df_trans_weather', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,741 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,742 INFO sqlalchemy.engine.Engine [generated in 0.00054s] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,744 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,744 INFO sqlalchemy.engine.Engine [generated in 0.00049s] {'param_1': 'v', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,744 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:52,744 INFO sqlalchemy.engine.Engine [cached since 0.006707s ago] {'param_1': 'm', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:52,762 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_attribute.attname AS name, pg_catalog.format_type(pg_catalog.pg_attribute.atttypid, pg_catalog.pg_attribute.atttypmod) AS format_type, (SELECT pg_catalog.pg_get_expr(pg_catalog.pg_attrdef.adbin, pg_catalog.pg_attrdef.adrelid) AS pg_get_expr_1
# FROM pg_catalog.pg_attrdef
# WHERE pg_catalog.pg_attrdef.adrelid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attrdef.adnum = pg_catalog.pg_attribute.attnum AND pg_catalog.pg_attribute.atthasdef) AS "default", pg_catalog.pg_attribute.attnotnull AS not_null, pg_catalog.pg_class.relname AS table_name, pg_catalog.pg_description.description AS comment, pg_catalog.pg_attribute.attgenerated AS generated, (SELECT json_build_object(%(json_build_object_2)s, pg_catalog.pg_attribute.attidentity = %(attidentity_1)s, %(json_build_object_3)s, pg_catalog.pg_sequence.seqstart, %(json_build_object_4)s, pg_catalog.pg_sequence.seqincrement, %(json_build_object_5)s, pg_catalog.pg_sequence.seqmin, %(json_build_object_6)s, pg_catalog.pg_sequence.seqmax, %(json_build_object_7)s, pg_catalog.pg_sequence.seqcache, %(json_build_object_8)s, pg_catalog.pg_sequence.seqcycle) AS json_build_object_1
# FROM pg_catalog.pg_sequence
# WHERE pg_catalog.pg_attribute.attidentity != %(attidentity_2)s AND pg_catalog.pg_sequence.seqrelid = CAST(CAST(pg_catalog.pg_get_serial_sequence(CAST(CAST(pg_catalog.pg_attribute.attrelid AS REGCLASS) AS TEXT), pg_catalog.pg_attribute.attname) AS REGCLASS) AS OID)) AS identity_options
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_class.oid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attribute.attnum > %(attnum_1)s AND NOT pg_catalog.pg_attribute.attisdropped LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_description.objsubid = pg_catalog.pg_attribute.attnum JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_attribute.attnum
# 2025-07-08 08:01:52,763 INFO sqlalchemy.engine.Engine [generated in 0.00058s] {'json_build_object_2': 'always', 'attidentity_1': 'a', 'json_build_object_3': 'start', 'json_build_object_4': 'increment', 'json_build_object_5': 'minvalue', 'json_build_object_6': 'maxvalue', 'json_build_object_7': 'cache', 'json_build_object_8': 'cycle', 'attidentity_2': '', 'attnum_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_weather'}
# 2025-07-08 08:01:52,769 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.format_type(pg_catalog.pg_type.typbasetype, pg_catalog.pg_type.typtypmod) AS attype, NOT pg_catalog.pg_type.typnotnull AS nullable, pg_catalog.pg_type.typdefault AS "default", pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, domain_constraints.condefs, domain_constraints.connames
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_constraint.contypid AS contypid, array_agg(pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s)) AS condefs, array_agg(pg_catalog.pg_constraint.conname) AS connames
# FROM pg_catalog.pg_constraint
# WHERE pg_catalog.pg_constraint.contypid != %(contypid_1)s GROUP BY pg_catalog.pg_constraint.contypid) AS domain_constraints ON pg_catalog.pg_type.oid = domain_constraints.contypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2025-07-08 08:01:52,769 INFO sqlalchemy.engine.Engine [generated in 0.00055s] {'pg_get_constraintdef_1': True, 'contypid_1': 0, 'typtype_1': 'd'}
# 2025-07-08 08:01:52,777 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, lbl_agg.labels AS labels
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_enum.enumtypid AS enumtypid, array_agg(pg_catalog.pg_enum.enumlabel ORDER BY pg_catalog.pg_enum.enumsortorder) AS labels
# FROM pg_catalog.pg_enum GROUP BY pg_catalog.pg_enum.enumtypid) AS lbl_agg ON pg_catalog.pg_type.oid = lbl_agg.enumtypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2025-07-08 08:01:52,777 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {'typtype_1': 'e'}
# 2025-07-08 08:01:52,777 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.oid, pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2025-07-08 08:01:52,777 INFO sqlalchemy.engine.Engine [generated in 0.00052s] {'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_weather'}
# 2025-07-08 08:01:52,794 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2025-07-08 08:01:52,794 INFO sqlalchemy.engine.Engine [generated in 0.00058s] {'generate_subscripts_1': 1, 'contype': 'p', 'oids_1': 16769}
# 2025-07-08 08:01:52,794 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, nsp_ref.nspname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_class AS cls_ref ON cls_ref.oid = pg_catalog.pg_constraint.confrelid LEFT OUTER JOIN pg_catalog.pg_namespace AS nsp_ref ON cls_ref.relnamespace = nsp_ref.oid LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2025-07-08 08:01:52,794 INFO sqlalchemy.engine.Engine [generated in 0.00049s] {'pg_get_constraintdef_1': True, 'contype_1': 'f', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_weather'}
# 2025-07-08 08:01:52,815 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_index.indrelid, cls_idx.relname AS relname_index, pg_catalog.pg_index.indisunique, pg_catalog.pg_constraint.conrelid IS NOT NULL AS has_constraint, pg_catalog.pg_index.indoption, cls_idx.reloptions, pg_catalog.pg_am.amname, CASE WHEN (pg_catalog.pg_index.indpred IS NOT NULL) THEN pg_catalog.pg_get_expr(pg_catalog.pg_index.indpred, pg_catalog.pg_index.indrelid) ELSE NULL END AS filter_definition, pg_catalog.pg_index.indnkeyatts, idx_cols.elements, idx_cols.elements_is_expr
# FROM pg_catalog.pg_index JOIN pg_catalog.pg_class AS cls_idx ON pg_catalog.pg_index.indexrelid = cls_idx.oid JOIN pg_catalog.pg_am ON cls_idx.relam = pg_catalog.pg_am.oid LEFT OUTER JOIN (SELECT idx_attr.indexrelid AS indexrelid, min(idx_attr.indrelid) AS min_1, array_agg(idx_attr.element ORDER BY idx_attr.ord) AS elements, array_agg(idx_attr.is_expr ORDER BY idx_attr.ord) AS elements_is_expr
# FROM (SELECT idx.indexrelid AS indexrelid, idx.indrelid AS indrelid, idx.ord AS ord, CASE WHEN (idx.attnum = %(attnum_1)s) THEN pg_catalog.pg_get_indexdef(idx.indexrelid, idx.ord + %(ord_1)s, %(pg_get_indexdef_1)s) ELSE pg_catalog.pg_attribute.attname END AS element, idx.attnum = %(attnum_2)s AS is_expr
# FROM (SELECT pg_catalog.pg_index.indexrelid AS indexrelid, pg_catalog.pg_index.indrelid AS indrelid, unnest(pg_catalog.pg_index.indkey) AS attnum, generate_subscripts(pg_catalog.pg_index.indkey, %(generate_subscripts_1)s) AS ord
# FROM pg_catalog.pg_index
# WHERE NOT pg_catalog.pg_index.indisprimary AND pg_catalog.pg_index.indrelid IN (%(oids_1)s)) AS idx LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_attribute.attnum = idx.attnum AND pg_catalog.pg_attribute.attrelid = idx.indrelid
# WHERE idx.indrelid IN (%(oids_1)s)) AS idx_attr GROUP BY idx_attr.indexrelid) AS idx_cols ON pg_catalog.pg_index.indexrelid = idx_cols.indexrelid LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_index.indrelid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_index.indexrelid = pg_catalog.pg_constraint.conindid AND pg_catalog.pg_constraint.contype = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s])
# WHERE pg_catalog.pg_index.indrelid IN (%(oids_1)s) AND NOT pg_catalog.pg_index.indisprimary ORDER BY pg_catalog.pg_index.indrelid, cls_idx.relname
# 2025-07-08 08:01:52,815 INFO sqlalchemy.engine.Engine [generated in 0.00082s] {'attnum_1': 0, 'ord_1': 1, 'pg_get_indexdef_1': True, 'attnum_2': 0, 'generate_subscripts_1': 1, 'param_1': 'p', 'param_2': 'u', 'param_3': 'x', 'oids_1': 16769}
# 2025-07-08 08:01:52,824 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2025-07-08 08:01:52,824 INFO sqlalchemy.engine.Engine [cached since 0.02975s ago] {'generate_subscripts_1': 1, 'contype': 'u', 'oids_1': 16769}
# 2025-07-08 08:01:52,827 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_class.oid = pg_catalog.pg_description.objoid AND pg_catalog.pg_description.objsubid = %(objsubid_1)s JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2025-07-08 08:01:52,827 INFO sqlalchemy.engine.Engine [generated in 0.00070s] {'objsubid_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_weather'}
# 2025-07-08 08:01:52,827 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2025-07-08 08:01:52,827 INFO sqlalchemy.engine.Engine [generated in 0.00064s] {'pg_get_constraintdef_1': True, 'contype_1': 'c', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'df_trans_weather'}
# 2025-07-08 08:01:52,844 INFO sqlalchemy.engine.Engine
# DROP TABLE df_trans_weather
# 2025-07-08 08:01:52,844 INFO sqlalchemy.engine.Engine [no key 0.00049s] {}
# 2025-07-08 08:01:52,844 INFO sqlalchemy.engine.Engine
# CREATE TABLE df_trans_weather (
# 	"City_id" TEXT,
# 	"City" TEXT,
# 	"City_lat" FLOAT(53),
# 	"City_long" FLOAT(53),
# 	"Date" TEXT,
# 	"Température max (°C)" BIGINT,
# 	"Vent max (m/s)" BIGINT,
# 	"Force vent" BIGINT,
# 	"Angle vent (°)" BIGINT,
# 	"Indice UV" FLOAT(53),
# 	"Icon" TEXT,
# 	"Emoji" TEXT,
# 	"Weather_description" TEXT
# )
#
#
# 2025-07-08 08:01:52,844 INFO sqlalchemy.engine.Engine [no key 0.00046s] {}
# 2025-07-08 08:01:52,862 INFO sqlalchemy.engine.Engine INSERT INTO df_trans_weather ("City_id", "City", "City_lat", "City_long", "Date", "Température max (°C)", "Vent max (m/s)", "Force vent", "Angle vent (°)", "Indice UV", "Icon", "Emoji", "Weather_description") VALUES (%(City_id__0)s, %(City__0)s, %(Ci ... 74594 characters truncated ... le_vent_A°Z__279)s, %(Indice_UV__279)s, %(Icon__279)s, %(Emoji__279)s, %(Weather_description__279)s)
# 2025-07-08 08:01:52,862 INFO sqlalchemy.engine.Engine [generated in 0.00210s (insertmanyvalues)] {'City_id__0': 'FR000001', 'Vent_max_Am/sZ__0': 7, 'City_long__0': -1.51146, 'Force_vent__0': 4, 'City_lat__0': 48.6359541, 'Date__0': '2025-07-08', 'Indice_UV__0': 7.73, 'Icon__0': '10d', 'Emoji__0': '🌦️', 'Angle_vent_A°Z__0': 311, 'Weather_description__0': 'Pluie intermittente', 'Température_max_A°CZ__0': 19, 'City__0': 'Mont Saint Michel', 'City_id__1': 'FR000001', 'Vent_max_Am/sZ__1': 5, 'City_long__1': -1.51146, 'Force_vent__1': 3, 'City_lat__1': 48.6359541, 'Date__1': '2025-07-09', 'Indice_UV__1': 7.77, 'Icon__1': '01d', 'Emoji__1': '☀️', 'Angle_vent_A°Z__1': 326, 'Weather_description__1': 'Ciel dégagé', 'Température_max_A°CZ__1': 23, 'City__1': 'Mont Saint Michel', 'City_id__2': 'FR000001', 'Vent_max_Am/sZ__2': 6, 'City_long__2': -1.51146, 'Force_vent__2': 4, 'City_lat__2': 48.6359541, 'Date__2': '2025-07-10', 'Indice_UV__2': 7.97, 'Icon__2': '01d', 'Emoji__2': '☀️', 'Angle_vent_A°Z__2': 325, 'Weather_description__2': 'Ciel dégagé', 'Température_max_A°CZ__2': 27, 'City__2': 'Mont Saint Michel', 'City_id__3': 'FR000001', 'Vent_max_Am/sZ__3': 6, 'City_long__3': -1.51146, 'Force_vent__3': 4, 'City_lat__3': 48.6359541, 'Date__3': '2025-07-11', 'Indice_UV__3': 7.88, 'Icon__3': '02d', 'Emoji__3': '🌤️', 'Angle_vent_A°Z__3': 52, 'Weather_description__3': 'Peu nuageux' ... 3540 parameters truncated ... 'City_long__276': -1.1515951, 'Force_vent__276': 5, 'City_lat__276': 46.159732, 'Date__276': '2025-07-12', 'Indice_UV__276': 8.07, 'Icon__276': '03d', 'Emoji__276': '⛅', 'Angle_vent_A°Z__276': 64, 'Weather_description__276': 'Nuages épars', 'Température_max_A°CZ__276': 26, 'City__276': 'La Rochelle', 'City_id__277': 'FR000035', 'Vent_max_Am/sZ__277': 7, 'City_long__277': -1.1515951, 'Force_vent__277': 4, 'City_lat__277': 46.159732, 'Date__277': '2025-07-13', 'Indice_UV__277': 9.0, 'Icon__277': '01d', 'Emoji__277': '☀️', 'Angle_vent_A°Z__277': 203, 'Weather_description__277': 'Ciel dégagé', 'Température_max_A°CZ__277': 24, 'City__277': 'La Rochelle', 'City_id__278': 'FR000035', 'Vent_max_Am/sZ__278': 7, 'City_long__278': -1.1515951, 'Force_vent__278': 4, 'City_lat__278': 46.159732, 'Date__278': '2025-07-14', 'Indice_UV__278': 9.0, 'Icon__278': '10d', 'Emoji__278': '🌦️', 'Angle_vent_A°Z__278': 282, 'Weather_description__278': 'Pluie intermittente', 'Température_max_A°CZ__278': 23, 'City__278': 'La Rochelle', 'City_id__279': 'FR000035', 'Vent_max_Am/sZ__279': 10, 'City_long__279': -1.1515951, 'Force_vent__279': 5, 'City_lat__279': 46.159732, 'Date__279': '2025-07-15', 'Indice_UV__279': 9.0, 'Icon__279': '02d', 'Emoji__279': '🌤️', 'Angle_vent_A°Z__279': 299, 'Weather_description__279': 'Peu nuageux', 'Température_max_A°CZ__279': 22, 'City__279': 'La Rochelle'}
# 2025-07-08 08:01:52,897 INFO sqlalchemy.engine.Engine COMMIT
# 280

# %% [markdown]
# ## Database (fusion+ export SQL)

# %%
def merge_dataframes_on_city_id(df1, df2):
    # Supprime les colonnes du df2 déjà présentes dans df1 (hors City_id)
    df2_clean = df2.drop(columns=[col for col in df2.columns if col in df1.columns and col != "City_id"])
    return pd.merge(df1, df2_clean, on="City_id", how="inner")

# Fusion city + hotels
merged_city_hotels = merge_dataframes_on_city_id(df_trans_city, df_trans_hotels)

# Fusion avec météo
df_final = merge_dataframes_on_city_id(merged_city_hotels, df_trans_weather)

# ✅ Affichage des dimensions
print(f"✅ La fusion des dataframes contient :\n{df_final.shape[0]} lignes\n{df_final.shape[1]} colonnes")

# export CSV
df_final.to_csv("D:/jedha/full_stack/projet/Scraping_Kayak/database.csv", index=False, encoding="utf-8-sig")
print("[✅] database exportée.")

# Initialisation client S3
s3 = boto3.client(
    "s3",
    region_name=region,
    aws_access_key_id=access_key,
    aws_secret_access_key=secret_key)

print("✅ Database envoyés avec succès vers S3.")

# Aperçu
display(df_final.head(2))
# Out:
# ✅ La fusion des dataframes contient :
# 6984 lignes
# 20 colonnes
# [✅] database exportée.
# ✅ Database envoyés avec succès vers S3.
#     City_id               City   City_lat  City_long                     Nom  \
# 0  FR000001  Mont Saint Michel  48.635954   -1.51146  Le Relais Saint Michel
# 1  FR000001  Mont Saint Michel  48.635954   -1.51146  Le Relais Saint Michel
#
#                                                  Url Note  \
# 0  https://www.booking.com/hotel/fr/le-relais-sai...  8,2
# 1  https://www.booking.com/hotel/fr/le-relais-sai...  8,2
#
#                                           Adresse  \
# 0  La Caserne, 50170 Le Mont-Saint-Michel, France
# 1  La Caserne, 50170 Le Mont-Saint-Michel, France
#
#                                         Points_forts  Hotel_lat  Hotel_long  \
# 0  [Parking, Petit-déjeuner disponible, Vue, Anim...  48.617587   -1.510396
# 1  [Parking, Petit-déjeuner disponible, Vue, Anim...  48.617587   -1.510396
#
#          Date  Température max (°C)  Vent max (m/s)  Force vent  \
# 0  2025-07-08                    19               7           4
# 1  2025-07-09                    23               5           3
#
#    Angle vent (°)  Indice UV Icon Emoji  Weather_description
# 0             311       7.73  10d    🌦️  Pluie intermittente
# 1             326       7.77  01d    ☀️          Ciel dégagé

# %%
engine = create_engine(f"postgresql+psycopg2://licorne2lc:{PASSWORD}@{HOSTNAME}/{DBNAME}", echo=True)

df_final.to_sql("database", engine, if_exists="replace", index=False)
# Out:
# 2025-07-08 08:01:53,060 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-07-08 08:01:53,060 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:53,082 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-07-08 08:01:53,083 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:53,092 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-07-08 08:01:53,092 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-08 08:01:53,103 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-08 08:01:53,106 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:53,107 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {'table_name': 'database', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:53,111 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:53,111 INFO sqlalchemy.engine.Engine [cached since 0.01282s ago] {'table_name': 'database', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:53,125 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:53,126 INFO sqlalchemy.engine.Engine [generated in 0.00066s] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:53,144 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:53,144 INFO sqlalchemy.engine.Engine [generated in 0.00066s] {'param_1': 'v', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:53,150 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-08 08:01:53,150 INFO sqlalchemy.engine.Engine [cached since 0.007483s ago] {'param_1': 'm', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-07-08 08:01:53,158 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_attribute.attname AS name, pg_catalog.format_type(pg_catalog.pg_attribute.atttypid, pg_catalog.pg_attribute.atttypmod) AS format_type, (SELECT pg_catalog.pg_get_expr(pg_catalog.pg_attrdef.adbin, pg_catalog.pg_attrdef.adrelid) AS pg_get_expr_1
# FROM pg_catalog.pg_attrdef
# WHERE pg_catalog.pg_attrdef.adrelid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attrdef.adnum = pg_catalog.pg_attribute.attnum AND pg_catalog.pg_attribute.atthasdef) AS "default", pg_catalog.pg_attribute.attnotnull AS not_null, pg_catalog.pg_class.relname AS table_name, pg_catalog.pg_description.description AS comment, pg_catalog.pg_attribute.attgenerated AS generated, (SELECT json_build_object(%(json_build_object_2)s, pg_catalog.pg_attribute.attidentity = %(attidentity_1)s, %(json_build_object_3)s, pg_catalog.pg_sequence.seqstart, %(json_build_object_4)s, pg_catalog.pg_sequence.seqincrement, %(json_build_object_5)s, pg_catalog.pg_sequence.seqmin, %(json_build_object_6)s, pg_catalog.pg_sequence.seqmax, %(json_build_object_7)s, pg_catalog.pg_sequence.seqcache, %(json_build_object_8)s, pg_catalog.pg_sequence.seqcycle) AS json_build_object_1
# FROM pg_catalog.pg_sequence
# WHERE pg_catalog.pg_attribute.attidentity != %(attidentity_2)s AND pg_catalog.pg_sequence.seqrelid = CAST(CAST(pg_catalog.pg_get_serial_sequence(CAST(CAST(pg_catalog.pg_attribute.attrelid AS REGCLASS) AS TEXT), pg_catalog.pg_attribute.attname) AS REGCLASS) AS OID)) AS identity_options
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_class.oid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attribute.attnum > %(attnum_1)s AND NOT pg_catalog.pg_attribute.attisdropped LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_description.objsubid = pg_catalog.pg_attribute.attnum JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_attribute.attnum
# 2025-07-08 08:01:53,158 INFO sqlalchemy.engine.Engine [generated in 0.00081s] {'json_build_object_2': 'always', 'attidentity_1': 'a', 'json_build_object_3': 'start', 'json_build_object_4': 'increment', 'json_build_object_5': 'minvalue', 'json_build_object_6': 'maxvalue', 'json_build_object_7': 'cache', 'json_build_object_8': 'cycle', 'attidentity_2': '', 'attnum_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'database'}
# 2025-07-08 08:01:53,173 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.format_type(pg_catalog.pg_type.typbasetype, pg_catalog.pg_type.typtypmod) AS attype, NOT pg_catalog.pg_type.typnotnull AS nullable, pg_catalog.pg_type.typdefault AS "default", pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, domain_constraints.condefs, domain_constraints.connames
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_constraint.contypid AS contypid, array_agg(pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s)) AS condefs, array_agg(pg_catalog.pg_constraint.conname) AS connames
# FROM pg_catalog.pg_constraint
# WHERE pg_catalog.pg_constraint.contypid != %(contypid_1)s GROUP BY pg_catalog.pg_constraint.contypid) AS domain_constraints ON pg_catalog.pg_type.oid = domain_constraints.contypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2025-07-08 08:01:53,174 INFO sqlalchemy.engine.Engine [generated in 0.00074s] {'pg_get_constraintdef_1': True, 'contypid_1': 0, 'typtype_1': 'd'}
# 2025-07-08 08:01:53,182 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, lbl_agg.labels AS labels
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_enum.enumtypid AS enumtypid, array_agg(pg_catalog.pg_enum.enumlabel ORDER BY pg_catalog.pg_enum.enumsortorder) AS labels
# FROM pg_catalog.pg_enum GROUP BY pg_catalog.pg_enum.enumtypid) AS lbl_agg ON pg_catalog.pg_type.oid = lbl_agg.enumtypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2025-07-08 08:01:53,182 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {'typtype_1': 'e'}
# 2025-07-08 08:01:53,189 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.oid, pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2025-07-08 08:01:53,190 INFO sqlalchemy.engine.Engine [generated in 0.00054s] {'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'database'}
# 2025-07-08 08:01:53,197 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2025-07-08 08:01:53,197 INFO sqlalchemy.engine.Engine [generated in 0.00057s] {'generate_subscripts_1': 1, 'contype': 'p', 'oids_1': 16774}
# 2025-07-08 08:01:53,205 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, nsp_ref.nspname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_class AS cls_ref ON cls_ref.oid = pg_catalog.pg_constraint.confrelid LEFT OUTER JOIN pg_catalog.pg_namespace AS nsp_ref ON cls_ref.relnamespace = nsp_ref.oid LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2025-07-08 08:01:53,205 INFO sqlalchemy.engine.Engine [generated in 0.00070s] {'pg_get_constraintdef_1': True, 'contype_1': 'f', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'database'}
# 2025-07-08 08:01:53,206 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_index.indrelid, cls_idx.relname AS relname_index, pg_catalog.pg_index.indisunique, pg_catalog.pg_constraint.conrelid IS NOT NULL AS has_constraint, pg_catalog.pg_index.indoption, cls_idx.reloptions, pg_catalog.pg_am.amname, CASE WHEN (pg_catalog.pg_index.indpred IS NOT NULL) THEN pg_catalog.pg_get_expr(pg_catalog.pg_index.indpred, pg_catalog.pg_index.indrelid) ELSE NULL END AS filter_definition, pg_catalog.pg_index.indnkeyatts, idx_cols.elements, idx_cols.elements_is_expr
# FROM pg_catalog.pg_index JOIN pg_catalog.pg_class AS cls_idx ON pg_catalog.pg_index.indexrelid = cls_idx.oid JOIN pg_catalog.pg_am ON cls_idx.relam = pg_catalog.pg_am.oid LEFT OUTER JOIN (SELECT idx_attr.indexrelid AS indexrelid, min(idx_attr.indrelid) AS min_1, array_agg(idx_attr.element ORDER BY idx_attr.ord) AS elements, array_agg(idx_attr.is_expr ORDER BY idx_attr.ord) AS elements_is_expr
# FROM (SELECT idx.indexrelid AS indexrelid, idx.indrelid AS indrelid, idx.ord AS ord, CASE WHEN (idx.attnum = %(attnum_1)s) THEN pg_catalog.pg_get_indexdef(idx.indexrelid, idx.ord + %(ord_1)s, %(pg_get_indexdef_1)s) ELSE pg_catalog.pg_attribute.attname END AS element, idx.attnum = %(attnum_2)s AS is_expr
# FROM (SELECT pg_catalog.pg_index.indexrelid AS indexrelid, pg_catalog.pg_index.indrelid AS indrelid, unnest(pg_catalog.pg_index.indkey) AS attnum, generate_subscripts(pg_catalog.pg_index.indkey, %(generate_subscripts_1)s) AS ord
# FROM pg_catalog.pg_index
# WHERE NOT pg_catalog.pg_index.indisprimary AND pg_catalog.pg_index.indrelid IN (%(oids_1)s)) AS idx LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_attribute.attnum = idx.attnum AND pg_catalog.pg_attribute.attrelid = idx.indrelid
# WHERE idx.indrelid IN (%(oids_1)s)) AS idx_attr GROUP BY idx_attr.indexrelid) AS idx_cols ON pg_catalog.pg_index.indexrelid = idx_cols.indexrelid LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_index.indrelid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_index.indexrelid = pg_catalog.pg_constraint.conindid AND pg_catalog.pg_constraint.contype = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s])
# WHERE pg_catalog.pg_index.indrelid IN (%(oids_1)s) AND NOT pg_catalog.pg_index.indisprimary ORDER BY pg_catalog.pg_index.indrelid, cls_idx.relname
# 2025-07-08 08:01:53,206 INFO sqlalchemy.engine.Engine [generated in 0.00059s] {'attnum_1': 0, 'ord_1': 1, 'pg_get_indexdef_1': True, 'attnum_2': 0, 'generate_subscripts_1': 1, 'param_1': 'p', 'param_2': 'u', 'param_3': 'x', 'oids_1': 16774}
# 2025-07-08 08:01:53,219 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2025-07-08 08:01:53,219 INFO sqlalchemy.engine.Engine [cached since 0.02613s ago] {'generate_subscripts_1': 1, 'contype': 'u', 'oids_1': 16774}
# 2025-07-08 08:01:53,225 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_class.oid = pg_catalog.pg_description.objoid AND pg_catalog.pg_description.objsubid = %(objsubid_1)s JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2025-07-08 08:01:53,225 INFO sqlalchemy.engine.Engine [generated in 0.00068s] {'objsubid_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'database'}
# 2025-07-08 08:01:53,225 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2025-07-08 08:01:53,225 INFO sqlalchemy.engine.Engine [generated in 0.00047s] {'pg_get_constraintdef_1': True, 'contype_1': 'c', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'database'}
# 2025-07-08 08:01:53,244 INFO sqlalchemy.engine.Engine
# DROP TABLE database
# 2025-07-08 08:01:53,244 INFO sqlalchemy.engine.Engine [no key 0.00043s] {}
# 2025-07-08 08:01:53,244 INFO sqlalchemy.engine.Engine
# CREATE TABLE database (
# 	"City_id" TEXT,
# 	"City" TEXT,
# 	"City_lat" FLOAT(53),
# 	"City_long" FLOAT(53),
# 	"Nom" TEXT,
# 	"Url" TEXT,
# 	"Note" TEXT,
# 	"Adresse" TEXT,
# 	"Points_forts" TEXT,
# 	"Hotel_lat" FLOAT(53),
# 	"Hotel_long" FLOAT(53),
# 	"Date" TEXT,
# 	"Température max (°C)" BIGINT,
# 	"Vent max (m/s)" BIGINT,
# 	"Force vent" BIGINT,
# 	"Angle vent (°)" BIGINT,
# 	"Indice UV" FLOAT(53),
# 	"Icon" TEXT,
# 	"Emoji" TEXT,
# 	"Weather_description" TEXT
# )
#
#
# 2025-07-08 08:01:53,244 INFO sqlalchemy.engine.Engine [no key 0.00045s] {}
# 2025-07-08 08:01:53,319 INFO sqlalchemy.engine.Engine INSERT INTO database ("City_id", "City", "City_lat", "City_long", "Nom", "Url", "Note", "Adresse", "Points_forts", "Hotel_lat", "Hotel_long", "Date", "Température max (°C)", "Vent max (m/s)", "Force vent", "Angle vent (°)", "Indice UV", "Icon", "Emoj ... 394732 characters truncated ... le_vent_A°Z__999)s, %(Indice_UV__999)s, %(Icon__999)s, %(Emoji__999)s, %(Weather_description__999)s)
# 2025-07-08 08:01:53,319 INFO sqlalchemy.engine.Engine [generated in 0.04132s (insertmanyvalues)] {'City_lat__0': 48.6359541, 'Weather_description__0': 'Pluie intermittente', 'City_id__0': 'FR000001', 'City_long__0': -1.51146, 'Date__0': '2025-07-08', 'Hotel_lat__0': 48.6175872716489, 'Emoji__0': '🌦️', 'Angle_vent_A°Z__0': 311, 'Température_max_A°CZ__0': 19, 'Url__0': 'https://www.booking.com/hotel/fr/le-relais-saint-michel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgNWARoTYgBAZgBD ... (160 characters truncated) ... oup_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=review_score%3D80&srpvid=56a06e4db3c80481&srepoch=1742744476&from=searchresults', 'City__0': 'Mont Saint Michel', 'Points_forts__0': ['Parking', 'Petit-déjeuner disponible', 'Vue', 'Animaux admis', 'Équipements de cuisine', 'Le Relais Saint Michel'], 'Note__0': '8,2', 'Vent_max_Am/sZ__0': 7, 'Hotel_long__0': -1.51039615273476, 'Force_vent__0': 4, 'Nom__0': 'Le Relais Saint Michel', 'Icon__0': '10d', 'Adresse__0': 'La Caserne, 50170 Le Mont-Saint-Michel, France', 'Indice_UV__0': 7.73, 'City_lat__1': 48.6359541, 'Weather_description__1': 'Ciel dégagé', 'City_id__1': 'FR000001', 'City_long__1': -1.51146, 'Date__1': '2025-07-09', 'Hotel_lat__1': 48.6175872716489, 'Emoji__1': '☀️', 'Angle_vent_A°Z__1': 326, 'Température_max_A°CZ__1': 23, 'Url__1': 'https://www.booking.com/hotel/fr/le-relais-saint-michel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgNWARoTYgBAZgBD ... (160 characters truncated) ... oup_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=review_score%3D80&srpvid=56a06e4db3c80481&srepoch=1742744476&from=searchresults', 'City__1': 'Mont Saint Michel', 'Points_forts__1': ['Parking', 'Petit-déjeuner disponible', 'Vue', 'Animaux admis', 'Équipements de cuisine', 'Le Relais Saint Michel'], 'Note__1': '8,2', 'Vent_max_Am/sZ__1': 5, 'Hotel_long__1': -1.51039615273476, 'Force_vent__1': 3, 'Nom__1': 'Le Relais Saint Michel', 'Icon__1': '01d', 'Adresse__1': 'La Caserne, 50170 Le Mont-Saint-Michel, France', 'Indice_UV__1': 7.77, 'City_lat__2': 48.6359541, 'Weather_description__2': 'Ciel dégagé', 'City_id__2': 'FR000001', 'City_long__2': -1.51146, 'Date__2': '2025-07-10', 'Hotel_lat__2': 48.6175872716489, 'Emoji__2': '☀️', 'Angle_vent_A°Z__2': 325, 'Température_max_A°CZ__2': 27, 'Url__2': 'https://www.booking.com/hotel/fr/le-relais-saint-michel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCGHNlYXJjaF9tb250IHNhaW50IG1pY2hlbEgNWARoTYgBAZgBD ... (160 characters truncated) ... oup_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=review_score%3D80&srpvid=56a06e4db3c80481&srepoch=1742744476&from=searchresults' ... 19900 parameters truncated ... 'City__997': 'Rouen', 'Points_forts__997': ['L’hébergement entier est pour vous', 'Vue', 'Équipements de cuisine'], 'Note__997': '9,4', 'Vent_max_Am/sZ__997': 7, 'Hotel_long__997': 1.0865714, 'Force_vent__997': 4, 'Nom__997': 'Appartement confortable et élégant en centre ville', 'Icon__997': '01d', 'Adresse__997': '37 Rue Saint-Eloi, 76000 Rouen, France', 'Indice_UV__997': 8.0, 'City_lat__998': 49.4404591, 'Weather_description__998': 'Ciel dégagé', 'City_id__998': 'FR000005', 'City_long__998': 1.0939658, 'Date__998': '2025-07-14', 'Hotel_lat__998': 49.4408084, 'Emoji__998': '☀️', 'Angle_vent_A°Z__998': 352, 'Température_max_A°CZ__998': 33, 'Url__998': 'https://www.booking.com/hotel/fr/appartement-confortable-et-elegant-en-centre-ville.fr.html?aid=304142&label=gen173nr-1FCAQoggJCDHNlYXJjaF9yb3VlbkgNW ... (174 characters truncated) ... p_children=0&req_children=0&hpos=25&hapos=25&sr_order=popularity&nflt=review_score%3D80&srpvid=27696e5096980022&srepoch=1742744481&from=searchresults', 'City__998': 'Rouen', 'Points_forts__998': ['L’hébergement entier est pour vous', 'Vue', 'Équipements de cuisine'], 'Note__998': '9,4', 'Vent_max_Am/sZ__998': 5, 'Hotel_long__998': 1.0865714, 'Force_vent__998': 3, 'Nom__998': 'Appartement con ...
# 2025-07-08 08:01:53,423 INFO sqlalchemy.engine.Engine INSERT INTO database ("City_id", "City", "City_lat", "City_long", "Nom", "Url", "Note", "Adresse", "Points_forts", "Hotel_lat", "Hotel_long", "Date", "Température max (°C)", "Vent max (m/s)", "Force vent", "Angle vent (°)", "Indice UV", "Icon", "Emoj ... 394732 characters truncated ... le_vent_A°Z__999)s, %(Indice_UV__999)s, %(Icon__999)s, %(Emoji__999)s, %(Weather_description__999)s)
# 2025-07-08 08:01:53,423 INFO sqlalchemy.engine.Engine [insertmanyvalues batch 2 of 7] {'City_lat__0': 48.8588897, 'Weather_description__0': 'Pluie intermittente', 'City_id__0': 'FR000006', 'City_long__0': 2.320041, 'Date__0': '2025-07-08', 'Hotel_lat__0': 48.829033, 'Emoji__0': '🌦️', 'Angle_vent_A°Z__0': 344, 'Température_max_A°CZ__0': 24, 'Url__0': 'https://www.booking.com/hotel/fr/1-75-paris-le-charme.fr.html?aid=304142&label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBAZgBDbgBF8gBDNgBAegBAfg ... (142 characters truncated) ... oup_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=review_score%3D80&srpvid=68cd6e50702d02e5&srepoch=1742744482&from=searchresults', 'City__0': 'Paris', 'Points_forts__0': [], 'Note__0': '9,1', 'Vent_max_Am/sZ__0': 5, 'Hotel_long__0': 2.345503, 'Force_vent__0': 3, 'Nom__0': '1.75 Paris Le Charme', 'Icon__0': '10d', 'Adresse__0': '16 rue Vergniaud, 13e arr., 75013 Paris, France', 'Indice_UV__0': 6.99, 'City_lat__1': 48.8588897, 'Weather_description__1': 'Ciel dégagé', 'City_id__1': 'FR000006', 'City_long__1': 2.320041, 'Date__1': '2025-07-09', 'Hotel_lat__1': 48.829033, 'Emoji__1': '☀️', 'Angle_vent_A°Z__1': 4, 'Température_max_A°CZ__1': 26, 'Url__1': 'https://www.booking.com/hotel/fr/1-75-paris-le-charme.fr.html?aid=304142&label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBAZgBDbgBF8gBDNgBAegBAfg ... (142 characters truncated) ... oup_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=review_score%3D80&srpvid=68cd6e50702d02e5&srepoch=1742744482&from=searchresults', 'City__1': 'Paris', 'Points_forts__1': [], 'Note__1': '9,1', 'Vent_max_Am/sZ__1': 4, 'Hotel_long__1': 2.345503, 'Force_vent__1': 3, 'Nom__1': '1.75 Paris Le Charme', 'Icon__1': '01d', 'Adresse__1': '16 rue Vergniaud, 13e arr., 75013 Paris, France', 'Indice_UV__1': 7.54, 'City_lat__2': 48.8588897, 'Weather_description__2': 'Ciel dégagé', 'City_id__2': 'FR000006', 'City_long__2': 2.320041, 'Date__2': '2025-07-10', 'Hotel_lat__2': 48.829033, 'Emoji__2': '☀️', 'Angle_vent_A°Z__2': 37, 'Température_max_A°CZ__2': 28, 'Url__2': 'https://www.booking.com/hotel/fr/1-75-paris-le-charme.fr.html?aid=304142&label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBAZgBDbgBF8gBDNgBAegBAfg ... (142 characters truncated) ... oup_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=review_score%3D80&srpvid=68cd6e50702d02e5&srepoch=1742744482&from=searchresults' ... 19900 parameters truncated ... 'City__997': 'Colmar', 'Points_forts__997': ['Parking', 'Petit-déjeuner disponible', 'Animaux admis', 'Équipements de cuisine', 'Accessibilité'], 'Note__997': '9,0', 'Vent_max_Am/sZ__997': 3, 'Hotel_long__997': 7.346389726389361, 'Force_vent__997': 2, 'Nom__997': 'Colmar Hotel', 'Icon__997': '02d', 'Adresse__997': '14 route de Rouffach, 68000 Colmar, France', 'Indice_UV__997': 8.0, 'City_lat__998': 48.0777517, 'Weather_description__998': 'Pluie intermittente', 'City_id__998': 'FR000011', 'City_long__998': 7.3579641, 'Date__998': '2025-07-14', 'Hotel_lat__998': 48.070800737248675, 'Emoji__998': '🌦️', 'Angle_vent_A°Z__998': 304, 'Température_max_A°CZ__998': 31, 'Url__998': 'https://www.booking.com/hotel/fr/colmar.fr.html?aid=304142&label=gen173nr-1FCAQoggJCDXNlYXJjaF9jb2xtYXJIDVgEaE2IAQGYAQ24ARfIAQzYAQHoAQH4AQOIAgGoAgO4A ... (129 characters truncated) ... oup_children=0&req_children=0&hpos=2&hapos=2&sr_order=popularity&nflt=review_score%3D80&srpvid=eaf06e53d64206a0&srepoch=1742744487&from=searchresults', 'City__998': 'Colmar', 'Points_forts__998': ['Parking', 'Petit-déjeuner disponible', 'Animaux admis', 'Équipements de cuisine', 'Accessibilité'], 'Note__998': '9,0', 'Vent_max_Am/sZ__998': 4, 'Hotel_long__998': 7.346389726389361, 'Force_vent__998': 3, 'Nom__998': 'Colmar Hotel', 'Icon__998': '10d', 'Adresse__998': '14 route de Rouffach, 68000 Colmar, France', 'Indice_UV__998': 8.0, 'City_lat__999': 48.0777517, 'Weather_description__999': 'Ciel dégagé', 'City_id__999': 'FR000011', 'City_long__999': 7.3579641, 'Date__999': '2 ...
# 2025-07-08 08:01:53,506 INFO sqlalchemy.engine.Engine INSERT INTO database ("City_id", "City", "City_lat", "City_long", "Nom", "Url", "Note", "Adresse", "Points_forts", "Hotel_lat", "Hotel_long", "Date", "Température max (°C)", "Vent max (m/s)", "Force vent", "Angle vent (°)", "Indice UV", "Icon", "Emoj ... 394732 characters truncated ... le_vent_A°Z__999)s, %(Indice_UV__999)s, %(Icon__999)s, %(Emoji__999)s, %(Weather_description__999)s)
# 2025-07-08 08:01:53,506 INFO sqlalchemy.engine.Engine [insertmanyvalues batch 3 of 7] {'City_lat__0': 48.0777517, 'Weather_description__0': 'Pluie intermittente', 'City_id__0': 'FR000011', 'City_long__0': 7.3579641, 'Date__0': '2025-07-08', 'Hotel_lat__0': 48.072145213703, 'Emoji__0': '🌦️', 'Angle_vent_A°Z__0': 291, 'Température_max_A°CZ__0': 20, 'Url__0': 'https://www.booking.com/hotel/fr/quiet-corner.fr.html?aid=304142&label=gen173nr-1FCAQoggJCDXNlYXJjaF9jb2xtYXJIDVgEaE2IAQGYAQ24ARfIAQzYAQHoAQH4AQOIAgG ... (135 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=eaf06e53d64206a0&srepoch=1742744487&from=searchresults', 'City__0': 'Colmar', 'Points_forts__0': [], 'Note__0': '9,3', 'Vent_max_Am/sZ__0': 4, 'Hotel_long__0': 7.368550534393, 'Force_vent__0': 3, 'Nom__0': 'Quiet Corner', 'Icon__0': '10d', 'Adresse__0': '1er étage droite 10 rue du landwasser, 68000 Colmar, France', 'Indice_UV__0': 6.11, 'City_lat__1': 48.0777517, 'Weather_description__1': 'Nuages épars', 'City_id__1': 'FR000011', 'City_long__1': 7.3579641, 'Date__1': '2025-07-09', 'Hotel_lat__1': 48.072145213703, 'Emoji__1': '⛅', 'Angle_vent_A°Z__1': 77, 'Température_max_A°CZ__1': 24, 'Url__1': 'https://www.booking.com/hotel/fr/quiet-corner.fr.html?aid=304142&label=gen173nr-1FCAQoggJCDXNlYXJjaF9jb2xtYXJIDVgEaE2IAQGYAQ24ARfIAQzYAQHoAQH4AQOIAgG ... (135 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=eaf06e53d64206a0&srepoch=1742744487&from=searchresults', 'City__1': 'Colmar', 'Points_forts__1': [], 'Note__1': '9,3', 'Vent_max_Am/sZ__1': 3, 'Hotel_long__1': 7.368550534393, 'Force_vent__1': 2, 'Nom__1': 'Quiet Corner', 'Icon__1': '03d', 'Adresse__1': '1er étage droite 10 rue du landwasser, 68000 Colmar, France', 'Indice_UV__1': 7.66, 'City_lat__2': 48.0777517, 'Weather_description__2': 'Ciel dégagé', 'City_id__2': 'FR000011', 'City_long__2': 7.3579641, 'Date__2': '2025-07-10', 'Hotel_lat__2': 48.072145213703, 'Emoji__2': '☀️', 'Angle_vent_A°Z__2': 58, 'Température_max_A°CZ__2': 27, 'Url__2': 'https://www.booking.com/hotel/fr/quiet-corner.fr.html?aid=304142&label=gen173nr-1FCAQoggJCDXNlYXJjaF9jb2xtYXJIDVgEaE2IAQGYAQ24ARfIAQzYAQHoAQH4AQOIAgG ... (135 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=eaf06e53d64206a0&srepoch=1742744487&from=searchresults' ... 19900 parameters truncated ... 'City__997': 'Grenoble', 'Points_forts__997': ['Restaurant 1*'], 'Note__997': '8,5', 'Vent_max_Am/sZ__997': 2, 'Hotel_long__997': 5.7254467753939995, 'Force_vent__997': 2, 'Nom__997': 'The Babel Community Hôtel - Grenoble Bastille', 'Icon__997': '10d', 'Adresse__997': '15 Rue Maurice Gignoux, 38000 Grenoble, France', 'Indice_UV__997': 9.0, 'City_lat__998': 45.1875602, 'Weather_description__998': 'Pluie intermittente', 'City_id__998': 'FR000016', 'City_long__998': 5.7357819, 'Date__998': '2025-07-14', 'Hotel_lat__998': 45.195810837764, 'Emoji__998': '🌦️', 'Angle_vent_A°Z__998': 223, 'Température_max_A°CZ__998': 33, 'Url__998': 'https://www.booking.com/hotel/fr/apt-paisible-en-centre-ville-parking-salle-de-sport-bar-en-rooftop.fr.html?aid=304142&label=gen173nr-1FCAQoggJCD3NlY ... (192 characters truncated) ... oup_children=0&req_children=0&hpos=2&hapos=2&sr_order=popularity&nflt=review_score%3D80&srpvid=01ee6e554da708c4&srepoch=1742744493&from=searchresults', 'City__998': 'Grenoble', 'Points_forts__998': ['Restaurant 1*'], 'Note__998': '8,5', 'Vent_max_Am/sZ__998': 5, 'Hotel_long__998': 5.7254467753939995, 'Force_vent__998': 3, 'Nom__998': 'The Babel Community Hôtel - Grenoble Bastille', 'Icon__998': '10d', 'Adresse__998': '15 Rue Maurice Gignoux, 38000 Grenoble, France', 'Indice_UV__998': 9.0, 'City_lat__999': 45.1875602, 'Weather_description__999': 'Ciel dégagé', 'City_id__999': 'FR000016', 'City_long__999': 5.7357819, 'Date__999': '2025-07-15', 'Hotel_lat__999': 45.195810837764 ...
# 2025-07-08 08:01:53,605 INFO sqlalchemy.engine.Engine INSERT INTO database ("City_id", "City", "City_lat", "City_long", "Nom", "Url", "Note", "Adresse", "Points_forts", "Hotel_lat", "Hotel_long", "Date", "Température max (°C)", "Vent max (m/s)", "Force vent", "Angle vent (°)", "Indice UV", "Icon", "Emoj ... 394732 characters truncated ... le_vent_A°Z__999)s, %(Indice_UV__999)s, %(Icon__999)s, %(Emoji__999)s, %(Weather_description__999)s)
# 2025-07-08 08:01:53,605 INFO sqlalchemy.engine.Engine [insertmanyvalues batch 4 of 7] {'City_lat__0': 45.1875602, 'Weather_description__0': 'Pluie intermittente', 'City_id__0': 'FR000016', 'City_long__0': 5.7357819, 'Date__0': '2025-07-08', 'Hotel_lat__0': 45.18988406394267, 'Emoji__0': '🌦️', 'Angle_vent_A°Z__0': 349, 'Température_max_A°CZ__0': 27, 'Url__0': 'https://www.booking.com/hotel/fr/residilaverde-gare.fr.html?aid=304142&label=gen173nr-1FCAQoggJCD3NlYXJjaF9ncmVub2JsZUgNWARoTYgBAZgBDbgBF8gBDNgBAegBA ... (144 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=01ee6e554da708c4&srepoch=1742744493&from=searchresults', 'City__0': 'Grenoble', 'Points_forts__0': ['Possibilité d’avoir l’hébergement entier', 'Parking', 'Vue', 'Équipements de cuisine', 'Accessibilité'], 'Note__0': '8,8', 'Vent_max_Am/sZ__0': 6, 'Hotel_long__0': 5.716276913881302, 'Force_vent__0': 4, 'Nom__0': 'Appartements Residilaverde Gare', 'Icon__0': '10d', 'Adresse__0': '59 Avenue Alsace Lorraine, 38000 Grenoble, France', 'Indice_UV__0': 7.56, 'City_lat__1': 45.1875602, 'Weather_description__1': 'Ciel dégagé', 'City_id__1': 'FR000016', 'City_long__1': 5.7357819, 'Date__1': '2025-07-09', 'Hotel_lat__1': 45.18988406394267, 'Emoji__1': '☀️', 'Angle_vent_A°Z__1': 341, 'Température_max_A°CZ__1': 26, 'Url__1': 'https://www.booking.com/hotel/fr/residilaverde-gare.fr.html?aid=304142&label=gen173nr-1FCAQoggJCD3NlYXJjaF9ncmVub2JsZUgNWARoTYgBAZgBDbgBF8gBDNgBAegBA ... (144 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=01ee6e554da708c4&srepoch=1742744493&from=searchresults', 'City__1': 'Grenoble', 'Points_forts__1': ['Possibilité d’avoir l’hébergement entier', 'Parking', 'Vue', 'Équipements de cuisine', 'Accessibilité'], 'Note__1': '8,8', 'Vent_max_Am/sZ__1': 3, 'Hotel_long__1': 5.716276913881302, 'Force_vent__1': 2, 'Nom__1': 'Appartements Residilaverde Gare', 'Icon__1': '01d', 'Adresse__1': '59 Avenue Alsace Lorraine, 38000 Grenoble, France', 'Indice_UV__1': 8.83, 'City_lat__2': 45.1875602, 'Weather_description__2': 'Ciel dégagé', 'City_id__2': 'FR000016', 'City_long__2': 5.7357819, 'Date__2': '2025-07-10', 'Hotel_lat__2': 45.18988406394267, 'Emoji__2': '☀️', 'Angle_vent_A°Z__2': 340, 'Température_max_A°CZ__2': 27, 'Url__2': 'https://www.booking.com/hotel/fr/residilaverde-gare.fr.html?aid=304142&label=gen173nr-1FCAQoggJCD3NlYXJjaF9ncmVub2JsZUgNWARoTYgBAZgBDbgBF8gBDNgBAegBA ... (144 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=01ee6e554da708c4&srepoch=1742744493&from=searchresults' ... 19900 parameters truncated ... 'City__997': 'Marseille', 'Points_forts__997': ['Restaurant 1*'], 'Note__997': '8,0', 'Vent_max_Am/sZ__997': 5, 'Hotel_long__997': 5.3774478, 'Force_vent__997': 3, 'Nom__997': 'The Babel Community Hôtel - Vieux Port', 'Icon__997': '01d', 'Adresse__997': '21 Rue Haxo, 13001 Marseille, France', 'Indice_UV__997': 7.0, 'City_lat__998': 43.2961743, 'Weather_description__998': 'Ciel dégagé', 'City_id__998': 'FR000021', 'City_long__998': 5.3699525, 'Date__998': '2025-07-14', 'Hotel_lat__998': 43.2937579, 'Emoji__998': '☀️', 'Angle_vent_A°Z__998': 289, 'Température_max_A°CZ__998': 29, 'Url__998': 'https://www.booking.com/hotel/fr/grand-t1-vieux-port-salle-de-sport-amp-rooftop.fr.html?aid=304142&label=gen173nr-1FCAQoggJCEHNlYXJjaF9tYXJzZWlsbGVID ... (173 characters truncated) ... oup_children=0&req_children=0&hpos=2&hapos=2&sr_order=popularity&nflt=review_score%3D80&srpvid=b4256e583d660088&srepoch=1742744498&from=searchresults', 'City__998': 'Marseille', 'Points_forts__998': ['Restaurant 1*'], 'Note__998': '8,0', 'Vent_max_Am/sZ__998': 7, 'Hotel_long__998': 5.3774478, 'Force_vent__998': 4, 'Nom__998': 'The Babel Community Hôtel - Vieux Port', 'Icon__998': '01d', 'Adresse__998': '21 Rue Haxo, 13001 Marseille, France', 'Indice_UV__998': 7.0, 'City_lat_ ...
# 2025-07-08 08:01:53,690 INFO sqlalchemy.engine.Engine INSERT INTO database ("City_id", "City", "City_lat", "City_long", "Nom", "Url", "Note", "Adresse", "Points_forts", "Hotel_lat", "Hotel_long", "Date", "Température max (°C)", "Vent max (m/s)", "Force vent", "Angle vent (°)", "Indice UV", "Icon", "Emoj ... 394732 characters truncated ... le_vent_A°Z__999)s, %(Indice_UV__999)s, %(Icon__999)s, %(Emoji__999)s, %(Weather_description__999)s)
# 2025-07-08 08:01:53,690 INFO sqlalchemy.engine.Engine [insertmanyvalues batch 5 of 7] {'City_lat__0': 43.2961743, 'Weather_description__0': 'Ciel dégagé', 'City_id__0': 'FR000021', 'City_long__0': 5.3699525, 'Date__0': '2025-07-08', 'Hotel_lat__0': 43.2870352, 'Emoji__0': '☀️', 'Angle_vent_A°Z__0': 322, 'Température_max_A°CZ__0': 28, 'Url__0': 'https://www.booking.com/hotel/fr/breteuil-marseille1.fr.html?aid=304142&label=gen173nr-1FCAQoggJCEHNlYXJjaF9tYXJzZWlsbGVIDVgEaE2IAQGYAQ24ARfIAQzYAQHo ... (146 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=b4256e583d660088&srepoch=1742744498&from=searchresults', 'City__0': 'Marseille', 'Points_forts__0': ['L’hébergement entier est pour vous', 'Vue', 'Équipements de cuisine'], 'Note__0': '9,6', 'Vent_max_Am/sZ__0': 16, 'Hotel_long__0': 5.3770764, 'Force_vent__0': 7, 'Nom__0': 'Très bel appartement avec une jolie vue dans le quartier prisé de Vauban', 'Icon__0': '01d', 'Adresse__0': '94 Rue Breteuil, Castellane et Préfecture, 13006 Marseille, France', 'Indice_UV__0': 8.61, 'City_lat__1': 43.2961743, 'Weather_description__1': 'Ciel dégagé', 'City_id__1': 'FR000021', 'City_long__1': 5.3699525, 'Date__1': '2025-07-09', 'Hotel_lat__1': 43.2870352, 'Emoji__1': '☀️', 'Angle_vent_A°Z__1': 328, 'Température_max_A°CZ__1': 26, 'Url__1': 'https://www.booking.com/hotel/fr/breteuil-marseille1.fr.html?aid=304142&label=gen173nr-1FCAQoggJCEHNlYXJjaF9tYXJzZWlsbGVIDVgEaE2IAQGYAQ24ARfIAQzYAQHo ... (146 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=b4256e583d660088&srepoch=1742744498&from=searchresults', 'City__1': 'Marseille', 'Points_forts__1': ['L’hébergement entier est pour vous', 'Vue', 'Équipements de cuisine'], 'Note__1': '9,6', 'Vent_max_Am/sZ__1': 13, 'Hotel_long__1': 5.3770764, 'Force_vent__1': 6, 'Nom__1': 'Très bel appartement avec une jolie vue dans le quartier prisé de Vauban', 'Icon__1': '01d', 'Adresse__1': '94 Rue Breteuil, Castellane et Préfecture, 13006 Marseille, France', 'Indice_UV__1': 9.08, 'City_lat__2': 43.2961743, 'Weather_description__2': 'Ciel dégagé', 'City_id__2': 'FR000021', 'City_long__2': 5.3699525, 'Date__2': '2025-07-10', 'Hotel_lat__2': 43.2870352, 'Emoji__2': '☀️', 'Angle_vent_A°Z__2': 168, 'Température_max_A°CZ__2': 26, 'Url__2': 'https://www.booking.com/hotel/fr/breteuil-marseille1.fr.html?aid=304142&label=gen173nr-1FCAQoggJCEHNlYXJjaF9tYXJzZWlsbGVIDVgEaE2IAQGYAQ24ARfIAQzYAQHo ... (146 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=b4256e583d660088&srepoch=1742744498&from=searchresults' ... 19900 parameters truncated ... 'City__997': 'Aigues Mortes', 'Points_forts__997': [], 'Note__997': '8,7', 'Vent_max_Am/sZ__997': 6, 'Hotel_long__997': 4.19366168974193, 'Force_vent__997': 4, 'Nom__997': 'Hôtel Le Médiéval', 'Icon__997': '10d', 'Adresse__997': '221 Avenue Du Pont De Provence, 30220 Aigues-Mortes, France', 'Indice_UV__997': 6.0, 'City_lat__998': 43.5661521, 'Weather_description__998': 'Ciel dégagé', 'City_id__998': 'FR000026', 'City_long__998': 4.19154, 'Date__998': '2025-07-14', 'Hotel_lat__998': 43.57186625316511, 'Emoji__998': '☀️', 'Angle_vent_A°Z__998': 257, 'Température_max_A°CZ__998': 28, 'Url__998': 'https://www.booking.com/hotel/fr/le-medieval.fr.html?aid=304142&label=gen173nr-1FCAQoggJCFHNlYXJjaF9haWd1ZXMgbW9ydGVzSA1YBGhNiAEBmAENuAEXyAEM2AEB6AEB ... (144 characters truncated) ... oup_children=0&req_children=0&hpos=2&hapos=2&sr_order=popularity&nflt=review_score%3D80&srpvid=5f4c6e5be879094b&srepoch=1742744504&from=searchresults', 'City__998': 'Aigues Mortes', 'Points_forts__998': [], 'Note__998': '8,7', 'Vent_max_Am/sZ__998': 12, 'Hotel_long__998': 4.19366168974193, 'Force_vent__998': 6, 'Nom__998': 'Hôtel Le Médiéval', 'Icon__998': '01d', 'Adresse__998': '221 Avenue Du Pont De Provence, 30220 Aigues-Mortes, France', 'Indice_UV__998': 6.0, ' ...
# 2025-07-08 08:01:53,796 INFO sqlalchemy.engine.Engine INSERT INTO database ("City_id", "City", "City_lat", "City_long", "Nom", "Url", "Note", "Adresse", "Points_forts", "Hotel_lat", "Hotel_long", "Date", "Température max (°C)", "Vent max (m/s)", "Force vent", "Angle vent (°)", "Indice UV", "Icon", "Emoj ... 394732 characters truncated ... le_vent_A°Z__999)s, %(Indice_UV__999)s, %(Icon__999)s, %(Emoji__999)s, %(Weather_description__999)s)
# 2025-07-08 08:01:53,797 INFO sqlalchemy.engine.Engine [insertmanyvalues batch 6 of 7] {'City_lat__0': 43.5661521, 'Weather_description__0': 'Ciel dégagé', 'City_id__0': 'FR000026', 'City_long__0': 4.19154, 'Date__0': '2025-07-08', 'Hotel_lat__0': 43.574094, 'Emoji__0': '☀️', 'Angle_vent_A°Z__0': 6, 'Température_max_A°CZ__0': 29, 'Url__0': 'https://www.booking.com/hotel/fr/residence-odalys-fleur-de-sel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCFHNlYXJjaF9haWd1ZXMgbW9ydGVzSA1YBGhNiAEBmA ... (162 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=5f4c6e5be879094b&srepoch=1742744504&from=searchresults', 'City__0': 'Aigues Mortes', 'Points_forts__0': ['Parking', 'Piscine', 'Vue', 'Animaux admis', 'Équipements de cuisine'], 'Note__0': '8,4', 'Vent_max_Am/sZ__0': 10, 'Hotel_long__0': 4.179246, 'Force_vent__0': 5, 'Nom__0': 'Résidence Odalys Fleur de Sel', 'Icon__0': '01d', 'Adresse__0': '278 Chemin de Trouche, 30220 Aigues-Mortes, France', 'Indice_UV__0': 8.56, 'City_lat__1': 43.5661521, 'Weather_description__1': 'Ciel dégagé', 'City_id__1': 'FR000026', 'City_long__1': 4.19154, 'Date__1': '2025-07-09', 'Hotel_lat__1': 43.574094, 'Emoji__1': '☀️', 'Angle_vent_A°Z__1': 11, 'Température_max_A°CZ__1': 27, 'Url__1': 'https://www.booking.com/hotel/fr/residence-odalys-fleur-de-sel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCFHNlYXJjaF9haWd1ZXMgbW9ydGVzSA1YBGhNiAEBmA ... (162 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=5f4c6e5be879094b&srepoch=1742744504&from=searchresults', 'City__1': 'Aigues Mortes', 'Points_forts__1': ['Parking', 'Piscine', 'Vue', 'Animaux admis', 'Équipements de cuisine'], 'Note__1': '8,4', 'Vent_max_Am/sZ__1': 8, 'Hotel_long__1': 4.179246, 'Force_vent__1': 5, 'Nom__1': 'Résidence Odalys Fleur de Sel', 'Icon__1': '01d', 'Adresse__1': '278 Chemin de Trouche, 30220 Aigues-Mortes, France', 'Indice_UV__1': 9.11, 'City_lat__2': 43.5661521, 'Weather_description__2': 'Ciel dégagé', 'City_id__2': 'FR000026', 'City_long__2': 4.19154, 'Date__2': '2025-07-10', 'Hotel_lat__2': 43.574094, 'Emoji__2': '☀️', 'Angle_vent_A°Z__2': 235, 'Température_max_A°CZ__2': 29, 'Url__2': 'https://www.booking.com/hotel/fr/residence-odalys-fleur-de-sel.fr.html?aid=304142&label=gen173nr-1FCAQoggJCFHNlYXJjaF9haWd1ZXMgbW9ydGVzSA1YBGhNiAEBmA ... (162 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=5f4c6e5be879094b&srepoch=1742744504&from=searchresults' ... 19900 parameters truncated ... 'City__997': 'Toulouse', 'Points_forts__997': [], 'Note__997': '8,8', 'Vent_max_Am/sZ__997': 4, 'Hotel_long__997': 1.4274835000000001, 'Force_vent__997': 3, 'Nom__997': 'Odalys City Toulouse Centre Compans Caffarelli', 'Icon__997': '10d', 'Adresse__997': '39 Rue du Béarnais, 31000 Toulouse, France', 'Indice_UV__997': 9.0, 'City_lat__998': 43.6044622, 'Weather_description__998': 'Pluie intermittente', 'City_id__998': 'FR000031', 'City_long__998': 1.4442469, 'Date__998': '2025-07-14', 'Hotel_lat__998': 43.6090789, 'Emoji__998': '🌦️', 'Angle_vent_A°Z__998': 303, 'Température_max_A°CZ__998': 37, 'Url__998': 'https://www.booking.com/hotel/fr/odalys-city-centre-compans-caffarelli.fr.html?aid=304142&label=gen173nr-1FCAQoggJCD3NlYXJjaF90b3Vsb3VzZUgNWARoTYgBAZ ... (163 characters truncated) ... oup_children=0&req_children=0&hpos=2&hapos=2&sr_order=popularity&nflt=review_score%3D80&srpvid=28e46e5e7ecb0637&srepoch=1742744510&from=searchresults', 'City__998': 'Toulouse', 'Points_forts__998': [], 'Note__998': '8,8', 'Vent_max_Am/sZ__998': 8, 'Hotel_long__998': 1.4274835000000001, 'Force_vent__998': 5, 'Nom__998': 'Odalys City Toulouse Centre Compans Caffarelli', 'Icon__998': '10d', 'Adresse__998': '39 Rue du Béarnais, 31000 Toulouse, France', 'Indice_UV__998': 9.0, 'City_lat__999': 43.6044622, 'Weather_description__999': 'Pluie intermittente', 'City_id__999': 'FR00003 ...
# 2025-07-08 08:01:53,883 INFO sqlalchemy.engine.Engine INSERT INTO database ("City_id", "City", "City_lat", "City_long", "Nom", "Url", "Note", "Adresse", "Points_forts", "Hotel_lat", "Hotel_long", "Date", "Température max (°C)", "Vent max (m/s)", "Force vent", "Angle vent (°)", "Indice UV", "Icon", "Emoj ... 388380 characters truncated ... le_vent_A°Z__983)s, %(Indice_UV__983)s, %(Icon__983)s, %(Emoji__983)s, %(Weather_description__983)s)
# 2025-07-08 08:01:53,883 INFO sqlalchemy.engine.Engine [insertmanyvalues batch 7 of 7] {'City_lat__0': 43.6044622, 'Weather_description__0': 'Ciel dégagé', 'City_id__0': 'FR000031', 'City_long__0': 1.4442469, 'Date__0': '2025-07-08', 'Hotel_lat__0': 43.60373648915114, 'Emoji__0': '☀️', 'Angle_vent_A°Z__0': 309, 'Température_max_A°CZ__0': 29, 'Url__0': 'https://www.booking.com/hotel/fr/crowne-plaza-toulouse-toulouse.fr.html?aid=304142&label=gen173nr-1FCAQoggJCD3NlYXJjaF90b3Vsb3VzZUgNWARoTYgBAZgBDbgBF ... (156 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=28e46e5e7ecb0637&srepoch=1742744510&from=searchresults', 'City__0': 'Toulouse', 'Points_forts__0': ['Parking', 'Petit-déjeuner disponible', 'Animaux admis', 'Vue', 'Équipements de cuisine', "L'ATRIUM"], 'Note__0': '8,2', 'Vent_max_Am/sZ__0': 6, 'Hotel_long__0': 1.4427535235881805, 'Force_vent__0': 4, 'Nom__0': 'Plaza Hotel Capitole Toulouse', 'Icon__0': '01d', 'Adresse__0': '7 Place du Capitole, 31000 Toulouse, France', 'Indice_UV__0': 8.81, 'City_lat__1': 43.6044622, 'Weather_description__1': 'Ciel dégagé', 'City_id__1': 'FR000031', 'City_long__1': 1.4442469, 'Date__1': '2025-07-09', 'Hotel_lat__1': 43.60373648915114, 'Emoji__1': '☀️', 'Angle_vent_A°Z__1': 337, 'Température_max_A°CZ__1': 31, 'Url__1': 'https://www.booking.com/hotel/fr/crowne-plaza-toulouse-toulouse.fr.html?aid=304142&label=gen173nr-1FCAQoggJCD3NlYXJjaF90b3Vsb3VzZUgNWARoTYgBAZgBDbgBF ... (156 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=28e46e5e7ecb0637&srepoch=1742744510&from=searchresults', 'City__1': 'Toulouse', 'Points_forts__1': ['Parking', 'Petit-déjeuner disponible', 'Animaux admis', 'Vue', 'Équipements de cuisine', "L'ATRIUM"], 'Note__1': '8,2', 'Vent_max_Am/sZ__1': 4, 'Hotel_long__1': 1.4427535235881805, 'Force_vent__1': 3, 'Nom__1': 'Plaza Hotel Capitole Toulouse', 'Icon__1': '01d', 'Adresse__1': '7 Place du Capitole, 31000 Toulouse, France', 'Indice_UV__1': 9.11, 'City_lat__2': 43.6044622, 'Weather_description__2': 'Ciel dégagé', 'City_id__2': 'FR000031', 'City_long__2': 1.4442469, 'Date__2': '2025-07-10', 'Hotel_lat__2': 43.60373648915114, 'Emoji__2': '☀️', 'Angle_vent_A°Z__2': 337, 'Température_max_A°CZ__2': 34, 'Url__2': 'https://www.booking.com/hotel/fr/crowne-plaza-toulouse-toulouse.fr.html?aid=304142&label=gen173nr-1FCAQoggJCD3NlYXJjaF90b3Vsb3VzZUgNWARoTYgBAZgBDbgBF ... (156 characters truncated) ... oup_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=review_score%3D80&srpvid=28e46e5e7ecb0637&srepoch=1742744510&from=searchresults' ... 19580 parameters truncated ... 'City__981': 'La Rochelle', 'Points_forts__981': ['L’hébergement entier est pour vous', 'Parking', 'Vue', 'Équipements de cuisine', 'Accessibilité'], 'Note__981': '9,2', 'Vent_max_Am/sZ__981': 7, 'Hotel_long__981': -1.1356104, 'Force_vent__981': 4, 'Nom__981': 'Ambre Appart-Wifi-Terrasse-Parking-Terrasse-2 couchages', 'Icon__981': '01d', 'Adresse__981': '40 Rue Berlioz, 17000 La Rochelle, France', 'Indice_UV__981': 9.0, 'City_lat__982': 46.159732, 'Weather_description__982': 'Pluie intermittente', 'City_id__982': 'FR000035', 'City_long__982': -1.1515951, 'Date__982': '2025-07-14', 'Hotel_lat__982': 46.1590071, 'Emoji__982': '🌦️', 'Angle_vent_A°Z__982': 282, 'Température_max_A°CZ__982': 23, 'Url__982': 'https://www.booking.com/hotel/fr/ambre-appart-wifi-terrasse-parking-terrasse-2-couchages.fr.html?aid=304142&label=gen173nr-1FCAQoggJCEnNlYXJjaF9sYSBy ... (187 characters truncated) ... p_children=0&req_children=0&hpos=25&hapos=25&sr_order=popularity&nflt=review_score%3D80&srpvid=db606e615c6c0b76&srepoch=1742744515&from=searchresults', 'City__982': 'La Rochelle', 'Points_forts__982': ['L’hébergement entier est pour vous', 'Parking', 'Vue', 'Équipements de cuisine', 'Accessibilité'], 'Note__982': '9,2', 'Vent_max_Am/sZ__982': 7, 'Hotel_long__982': -1.1356104, 'Force_vent__ ...
# 2025-07-08 08:01:53,956 INFO sqlalchemy.engine.Engine COMMIT
# 984
